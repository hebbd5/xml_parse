# %% [markdown]
# # XML to JSON Conversion

# %% [markdown]
# ## Load XML Data

# %%
xml_data = ""
xml_filepath = "Datasets/full_sanctions_list.xml"

with open(xml_filepath, "r") as file:
    xml_data = file.read()
    
print(type(xml_data))
print(len(xml_data))
# Out:
# <class 'str'>
# 91631773

# %% [markdown]
# ## Parse using BS4

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(xml_data, features='xml')

def xml_to_dict(element):
    
    if isinstance(element, str):
        return element
    
    if not element.contents:
        return element.string
    
    result = {}
    
    for child in element.children:
        
        if isinstance(child, str):
            continue
        
        if child.name not in result:
            result[child.name] = xml_to_dict(child)
            
        else:
            if not isinstance(result[child.name], list):
                result[child.name] = [result[child.name]]
            result[child.name].append(xml_to_dict(child))
            
    # Directly capture text nodes without 'text' key
    if element.string and element.string.strip():
        return element.string.strip()
    
    return result

xml_dict = xml_to_dict(soup)

# %%
xml_dict
# Out:
# {'sanctionsData': {'publicationInfo': {'dataAsOf': '2024-08-28T00:00:00',
#    'filters': {'sanctionsLists': {'sanctionsList': ['SDN List',
#       'Non-SDN Palestinian Legislative Council List',
#       'FSE List',
#       'Sectoral Sanctions Identifications List',
#       'Consolidated List',
#       'CAPTA List',
#       'Non-SDN Menu-Based Sanctions List',
#       'Non-SDN CMIC List']},
#     'sanctionsPrograms': {'sanctionsProgram': 'IRGC'}}},
#   'referenceValues': {'referenceValue': [{'type': 'Additional Sanctions Information -',
#      'value': 'Subject to Secondary Sanctions'},
#     {'type': 'Additional Sanctions Information -',
#      'value': 'Subject to Secondary Sanctions Pursuant to the Hizballah Financial Sanctions Regulations'},
#     {'type': 'ALIAS TYPE', 'value': 'A.K.A.'},
#     {'type': 'ALIAS TYPE', 'value': 'F.K.A.'},
#     {'type': 'ALIAS TYPE', 'value': 'N.K.A.'},
#     {'type': 'CAATSA Section 235 Information:',
#      'value': 'FOREIGN EXCHANGE. Sec 235(a)(7)'},
#     {'type': 'CAATSA Section 235 Information:',
#      'value': 'BANKING TRANSACTIONS. Sec 235(a)(8)'},
#     {'type': 'CAATSA Section 235 Information:',
#      'value': 'BAN ON INVESTMENT IN EQUITY OR DEBT OF SANCTIONED PERSON. Sec 235(a)(10)'},
#     {'type': 'CAATSA Section 235 Information:',
#      'value': 'EXCLUSION OF CORPORATE OFFICERS. Sec 235(a)(11)'},
#     {'type': 'CAATSA Section 235 Information:',
#      'value': 'SANCTIONS ON PRINCIPAL EXECUTIVE OFFICERS. Sec 235(a)(12)'},
#     {'type': 'CAATSA Section 235 Information:',
#      'value': 'EXPORT SANCTIONS Sec. 235(a)(2)'},
#     {'type': 'CAATSA Section 235 Information:',
#      'value': 'LOANS FROM UNITED STATES FINANCIAL INSTITUTIONS. Sec. 235(a)(3)'},
#     {'type': 'CAATSA Section 235 Information:',
#      'value': 'LOANS FROM INTERNATIONAL FINANCIAL INSTITUTIONS. Sec. 235(a)(4)'},
#     {'type': 'CAATSA Section 235 Information:',
#      'value': 'BLOCKING PROPERTY AND INTERESTS IN PROPERTY. Sec 235(a)(9)'},
#     {'type': 'CAATSA Section 235 Information:',
#      'value': 'EXPORT-IMPORT BANK ASSISTANCE FOR EXPORTS TO SANCTIONED PERSONS. Sec. 235(a)(1)'},
#     {'type': 'COUNTRY', 'value': 'Afghanistan', 'isoCode': 'AF'},
#     {'type': 'COUNTRY', 'value': 'Albania', 'isoCode': 'AL'},
#     {'type': 'COUNTRY', 'value': 'Algeria', 'isoCode': 'DZ'},
#     {'type': 'COUNTRY', 'value': 'Angola', 'isoCode': 'AO'},
#     {'type': 'COUNTRY', 'value': 'Antigua and Barbuda', 'isoCode': 'AG'},
#     {'type': 'COUNTRY', 'value': 'Argentina', 'isoCode': 'AR'},
#     {'type': 'COUNTRY', 'value': 'Armenia', 'isoCode': 'AM'},
#     {'type': 'COUNTRY', 'value': 'Australia', 'isoCode': 'AU'},
#     {'type': 'COUNTRY', 'value': 'Austria', 'isoCode': 'AT'},
#     {'type': 'COUNTRY', 'value': 'Azerbaijan', 'isoCode': 'AZ'},
#     {'type': 'COUNTRY', 'value': 'Bahamas, The', 'isoCode': 'BS'},
#     {'type': 'COUNTRY', 'value': 'Bahrain', 'isoCode': 'BH'},
#     {'type': 'COUNTRY', 'value': 'Bangladesh', 'isoCode': 'BD'},
#     {'type': 'COUNTRY', 'value': 'Barbados', 'isoCode': 'BB'},
#     {'type': 'COUNTRY', 'value': 'Belarus', 'isoCode': 'BY'},
#     {'type': 'COUNTRY', 'value': 'Belgium', 'isoCode': 'BE'},
#     {'type': 'COUNTRY', 'value': 'Belize', 'isoCode': 'BZ'},
#     {'type': 'COUNTRY', 'value': 'Benin', 'isoCode': 'BJ'},
#     {'type': 'COUNTRY', 'value': 'Bolivia', 'isoCode': 'BO'},
#     {'type': 'COUNTRY', 'value': 'Bosnia and Herzegovina', 'isoCode': 'BA'},
#     {'type': 'COUNTRY', 'value': 'Brazil', 'isoCode': 'BR'},
#     {'type': 'COUNTRY', 'value': 'Brunei', 'isoCode': 'BN'},
#     {'type': 'COUNTRY', 'value': 'Bulgaria', 'isoCode': 'BG'},
#     {'type': 'COUNTRY', 'value': 'Burkina Faso', 'isoCode': 'BF'},
#     {'type': 'COUNTRY', 'value': 'Burma', 'isoCode': 'MM'},
#     {'type': 'COUNTRY', 'value': 'Cambodia', 'isoCode': 'KH'},
#     {'type': 'COUNTRY', 'value': 'Cameroon', 'isoCode': 'CM'},
#     {'type': 'COUNTRY', 'value': 'Canada', 'isoCode': 'CA'},
#     {'type': 'COUNTRY', 'value': 'Cabo Verde', 'isoCode': 'CV'},
#     {'type': 'COUNTRY', 'value': 'Central African Republic', 'isoCode': 'CF'},
#     {'type': 'COUNTRY', 'value': 'Chad', 'isoCode': 'TD'},
#     {'type': 'COUNTRY', 'value': 'Chile', 'isoCode': 'CL'},
#     {'type': 'COUNTRY', 'value': 'China', 'isoCode': 'CN'},
#     {'type': 'COUNTRY', 'value': 'Colombia', 'isoCode': 'CO'},
#     {'type': 'COUNTRY', 'value': 'Comoros', 'isoCode': 'KM'},
#     {'type': 'COUNTRY', 'value': 'Congo, Republic of the', 'isoCode': 'CG'},
#     {'type': 'COUNTRY',
#      'value': 'Congo, Democratic Republic of the',
#      'isoCode': 'CD'},
#     {'type': 'COUNTRY', 'value': 'Costa Rica', 'isoCode': 'CR'},
#     {'type': 'COUNTRY', 'value': 'Cote d Ivoire', 'isoCode': 'CI'},
#     {'type': 'COUNTRY', 'value': 'Croatia', 'isoCode': 'HR'},
#     {'type': 'COUNTRY', 'value': 'Cuba', 'isoCode': 'CU'},
#     {'type': 'COUNTRY', 'value': 'Cyprus', 'isoCode': 'CY'},
#     {'type': 'COUNTRY', 'value': 'Czech Republic', 'isoCode': 'CZ'},
#     {'type': 'COUNTRY', 'value': 'Denmark', 'isoCode': 'DK'},
#     {'type': 'COUNTRY', 'value': 'Djibouti', 'isoCode': 'DJ'},
#     {'type': 'COUNTRY', 'value': 'Dominica', 'isoCode': 'DM'},
#     {'type': 'COUNTRY', 'value': 'Dominican Republic', 'isoCode': 'DO'},
#     {'type': 'COUNTRY', 'value': 'Ecuador', 'isoCode': 'EC'},
#     {'type': 'COUNTRY', 'value': 'Egypt', 'isoCode': 'EG'},
#     {'type': 'COUNTRY', 'value': 'El Salvador', 'isoCode': 'SV'},
#     {'type': 'COUNTRY', 'value': 'Equatorial Guinea', 'isoCode': 'GQ'},
#     {'type': 'COUNTRY', 'value': 'Eritrea', 'isoCode': 'ER'},
#     {'type': 'COUNTRY', 'value': 'Estonia', 'isoCode': 'EE'},
#     {'type': 'COUNTRY', 'value': 'Ethiopia', 'isoCode': 'ET'},
#     {'type': 'COUNTRY', 'value': 'Finland', 'isoCode': 'FI'},
#     {'type': 'COUNTRY', 'value': 'France', 'isoCode': 'FR'},
#     {'type': 'COUNTRY', 'value': 'The Gambia', 'isoCode': 'GM'},
#     {'type': 'COUNTRY', 'value': 'Georgia', 'isoCode': 'GE'},
#     {'type': 'COUNTRY', 'value': 'Germany', 'isoCode': 'DE'},
#     {'type': 'COUNTRY', 'value': 'Ghana', 'isoCode': 'GH'},
#     {'type': 'COUNTRY', 'value': 'Greece', 'isoCode': 'GR'},
#     {'type': 'COUNTRY', 'value': 'Guatemala', 'isoCode': 'GT'},
#     {'type': 'COUNTRY', 'value': 'Guinea', 'isoCode': 'GN'},
#     {'type': 'COUNTRY', 'value': 'Guinea-Bissau', 'isoCode': 'GW'},
#     {'type': 'COUNTRY', 'value': 'Guyana', 'isoCode': 'GY'},
#     {'type': 'COUNTRY', 'value': 'Haiti', 'isoCode': 'HT'},
#     {'type': 'COUNTRY', 'value': 'Honduras', 'isoCode': 'HN'},
#     {'type': 'COUNTRY', 'value': 'Hungary', 'isoCode': 'HU'},
#     {'type': 'COUNTRY', 'value': 'Iceland', 'isoCode': 'IS'},
#     {'type': 'COUNTRY', 'value': 'India', 'isoCode': 'IN'},
#     {'type': 'COUNTRY', 'value': 'Indonesia', 'isoCode': 'ID'},
#     {'type': 'COUNTRY', 'value': 'Iran', 'isoCode': 'IR'},
#     {'type': 'COUNTRY', 'value': 'Iraq', 'isoCode': 'IQ'},
#     {'type': 'COUNTRY', 'value': 'Ireland', 'isoCode': 'IE'},
#     {'type': 'COUNTRY', 'value': 'Israel', 'isoCode': 'IL'},
#     {'type': 'COUNTRY', 'value': 'Italy', 'isoCode': 'IT'},
#     {'type': 'COUNTRY', 'value': 'Jamaica', 'isoCode': 'JM'},
#     {'type': 'COUNTRY', 'value': 'Japan', 'isoCode': 'JP'},
#     {'type': 'COUNTRY', 'value': 'Jordan', 'isoCode': 'JO'},
#     {'type': 'COUNTRY', 'value': 'Kazakhstan', 'isoCode': 'KZ'},
#     {'type': 'COUNTRY', 'value': 'Kenya', 'isoCode': 'KE'},
#     {'type': 'COUNTRY', 'value': 'Korea, North', 'isoCode': 'KP'},
#     {'type': 'COUNTRY', 'value': 'Korea, South', 'isoCode': 'KR'},
#     {'type': 'COUNTRY', 'value': 'Kuwait', 'isoCode': 'KW'},
#     {'type': 'COUNTRY', 'value': 'Kyrgyzstan', 'isoCode': 'KG'},
#     {'type': 'COUNTRY', 'value': 'Laos', 'isoCode': 'LA'},
#     {'type': 'COUNTRY', 'value': 'Latvia', 'isoCode': 'LV'},
#     {'type': 'COUNTRY', 'value': 'Lebanon', 'isoCode': 'LB'},
#     {'type': 'COUNTRY', 'value': 'Liberia', 'isoCode': 'LR'},
#     {'type': 'COUNTRY', 'value': 'Libya', 'isoCode': 'LY'},
#     {'type': 'COUNTRY', 'value': 'Liechtenstein', 'isoCode': 'LI'},
#     {'type': 'COUNTRY', 'value': 'Lithuania', 'isoCode': 'LT'},
#     {'type': 'COUNTRY', 'value': 'Luxembourg', 'isoCode': 'LU'},
#     {'type': 'COUNTRY',
#      'value': 'North Macedonia, The Republic of',
#      'isoCode': 'MK'},
#     {'type': 'COUNTRY', 'value': 'Malaysia', 'isoCode': 'MY'},
#     {'type': 'COUNTRY', 'value': 'Maldives', 'isoCode': 'MV'},
#     {'type': 'COUNTRY', 'value': 'Mali', 'isoCode': 'ML'},
#     {'type': 'COUNTRY', 'value': 'Malta', 'isoCode': 'MT'},
#     {'type': 'COUNTRY', 'value': 'Marshall Islands', 'isoCode': 'MH'},
#     {'type': 'COUNTRY', 'value': 'Mauritania', 'isoCode': 'MR'},
#     {'type': 'COUNTRY', 'value': 'Mexico', 'isoCode': 'MX'},
#     {'type': 'COUNTRY', 'value': 'Moldova', 'isoCode': 'MD'},
#     {'type': 'COUNTRY', 'value': 'Monaco', 'isoCode': 'MC'},
#     {'type': 'COUNTRY', 'value': 'Mongolia', 'isoCode': 'MN'},
#     {'type': 'COUNTRY', 'value': 'Morocco', 'isoCode': 'MA'},
#     {'type': 'COUNTRY', 'value': 'Mozambique', 'isoCode': 'MZ'},
#     {'type': 'COUNTRY', 'value': 'Namibia', 'isoCode': 'NA'},
#     {'type': 'COUNTRY', 'value': 'Netherlands', 'isoCode': 'NL'},
#     {'type': 'COUNTRY', 'value': 'New Zealand', 'isoCode': 'NZ'},
#     {'type': 'COUNTRY', 'value': 'Nicaragua', 'isoCode': 'NI'},
#     {'type': 'COUNTRY', 'value': 'Niger', 'isoCode': 'NE'},
#     {'type': 'COUNTRY', 'value': 'Nigeria', 'isoCode': 'NG'},
#     {'type': 'COUNTRY', 'value': 'Norway', 'isoCode': 'NO'},
#     {'type': 'COUNTRY', 'value': 'Oman', 'isoCode': 'OM'},
#     {'type': 'COUNTRY', 'value': 'Pakistan', 'isoCode': 'PK'},
#     {'type': 'COUNTRY', 'value': 'Palau', 'isoCode': 'PW'},
#     {'type': 'COUNTRY', 'value': 'Panama', 'isoCode': 'PA'},
#     {'type': 'COUNTRY', 'value': 'Paraguay', 'isoCode': 'PY'},
#     {'type': 'COUNTRY', 'value': 'Peru', 'isoCode': 'PE'},
#     {'type': 'COUNTRY', 'value': 'Philippines', 'isoCode': 'PH'},
#     {'type': 'COUNTRY', 'value': 'Poland', 'isoCode': 'PL'},
#     {'type': 'COUNTRY', 'value': 'Portugal', 'isoCode': 'PT'},
#     {'type': 'COUNTRY', 'value': 'Qatar', 'isoCode': 'QA'},
#     {'type': 'COUNTRY', 'value': 'Romania', 'isoCode': 'RO'},
#     {'type': 'COUNTRY', 'value': 'Russia', 'isoCode': 'RU'},
#     {'type': 'COUNTRY', 'value': 'Rwanda', 'isoCode': 'RW'},
#     {'type': 'COUNTRY', 'value': 'Saint Kitts and Nevis', 'isoCode': 'KN'},
#     {'type': 'COUNTRY',
#      'value': 'Saint Vincent and the Grenadines',
#      'isoCode': 'VC'},
#     {'type': 'COUNTRY', 'value': 'Samoa', 'isoCode': 'WS'},
#     {'type': 'COUNTRY', 'value': 'San Marino', 'isoCode': 'SM'},
#     {'type': 'COUNTRY', 'value': 'Saudi Arabia', 'isoCode': 'SA'},
#     {'type': 'COUNTRY', 'value': 'Senegal', 'isoCode': 'SN'},
#     {'type': 'COUNTRY', 'value': 'Serbia', 'isoCode': 'RS'},
#     {'type': 'COUNTRY', 'value': 'Seychelles', 'isoCode': 'SC'},
#     {'type': 'COUNTRY', 'value': 'Sierra Leone', 'isoCode': 'SL'},
#     {'type': 'COUNTRY', 'value': 'Singapore', 'isoCode': 'SG'},
#     {'type': 'COUNTRY', 'value': 'Slovakia', 'isoCode': 'SK'},
#     {'type': 'COUNTRY', 'value': 'Slovenia', 'isoCode': 'SI'},
#     {'type': 'COUNTRY', 'value': 'Somalia', 'isoCode': 'SO'},
#     {'type': 'COUNTRY', 'value': 'South Africa', 'isoCode': 'ZA'},
#     {'type': 'COUNTRY', 'value': 'Spain', 'isoCode': 'ES'},
#     {'type': 'COUNTRY', 'value': 'Sri Lanka', 'isoCode': 'LK'},
#     {'type': 'COUNTRY', 'value': 'Sudan', 'isoCode': 'SD'},
#     {'type': 'COUNTRY', 'value': 'Sweden', 'isoCode': 'SE'},
#     {'type': 'COUNTRY', 'value': 'Switzerland', 'isoCode': 'CH'},
#     {'type': 'COUNTRY', 'value': 'Syria', 'isoCode': 'SY'},
#     {'type': 'COUNTRY', 'value': 'Tajikistan', 'isoCode': 'TJ'},
#     {'type': 'COUNTRY', 'value': 'Tanzania', 'isoCode': 'TZ'},
#     {'type': 'COUNTRY', 'value': 'Thailand', 'isoCode': 'TH'},
#     {'type': 'COUNTRY', 'value': 'Togo', 'isoCode': 'TG'},
#     {'type': 'COUNTRY', 'value': 'Trinidad and Tobago', 'isoCode': 'TT'},
#     {'type': 'COUNTRY', 'value': 'Tunisia', 'isoCode': 'TN'},
#     {'type': 'COUNTRY', 'value': 'Turkey', 'isoCode': 'TR'},
#     {'type': 'COUNTRY', 'value': 'Turkmenistan', 'isoCode': 'TM'},
#     {'type': 'COUNTRY', 'value': 'Uganda', 'isoCode': 'UG'},
#     {'type': 'COUNTRY', 'value': 'Ukraine', 'isoCode': 'UA'},
#     {'type': 'COUNTRY', 'value': 'United Arab Emirates', 'isoCode': 'AE'},
#     {'type': 'COUNTRY', 'value': 'United Kingdom', 'isoCode': 'GB'},
#     {'type': 'COUNTRY', 'value': 'United States', 'isoCode': 'US'},
#     {'type': 'COUNTRY', 'value': 'Uruguay', 'isoCode': 'UY'},
#     {'type': 'COUNTRY', 'value': 'Uzbekistan', 'isoCode': 'UZ'},
#     {'type': 'COUNTRY', 'value': 'Vanuatu', 'isoCode': 'VU'},
#     {'type': 'COUNTRY', 'value': 'Venezuela', 'isoCode': 'VE'},
#     {'type': 'COUNTRY', 'value': 'Vietnam', 'isoCode': 'VN'},
#     {'type': 'COUNTRY', 'value': 'Yemen', 'isoCode': 'YE'},
#     {'type': 'COUNTRY', 'value': 'Zambia', 'isoCode': 'ZM'},
#     {'type': 'COUNTRY', 'value': 'Zimbabwe', 'isoCode': 'ZW'},
#     {'type': 'COUNTRY', 'value': 'Aruba', 'isoCode': 'AW'},
#     {'type': 'COUNTRY', 'value': 'Bermuda', 'isoCode': 'BM'},
#     {'type': 'COUNTRY', 'value': 'Cayman Islands', 'isoCode': 'KY'},
#     {'type': 'COUNTRY', 'value': 'Gibraltar', 'isoCode': 'GI'},
#     {'type': 'COUNTRY', 'value': 'Guernsey', 'isoCode': 'GG'},
#     {'type': 'COUNTRY', 'value': 'Hong Kong', 'isoCode': 'HK'},
#     {'type': 'COUNTRY', 'value': 'Jersey', 'isoCode': 'JE'},
#     {'type': 'COUNTRY', 'value': 'Macau', 'isoCode': 'MO'},
#     {'type': 'COUNTRY', 'value': 'Man, Isle of', 'isoCode': 'IM'},
#     {'type': 'COUNTRY', 'value': 'Netherlands Antilles'},
#     {'type': 'COUNTRY', 'value': 'Virgin Islands, British', 'isoCode': 'VG'},
#     {'type': 'COUNTRY', 'value': 'undetermined'},
#     {'type': 'COUNTRY', 'value': 'West Bank'},
#     {'type': 'COUNTRY', 'value': 'Taiwan', 'isoCode': 'TW'},
#     {'type': 'COUNTRY', 'value': 'Palestinian', 'isoCode': 'PS'},
#     {'type': 'COUNTRY', 'value': 'Kosovo'},
#     {'type': 'COUNTRY', 'value': 'Montenegro', 'isoCode': 'ME'},
#     {'type': 'COUNTRY', 'value': 'Region: Northern Mali'},
#     {'type': 'COUNTRY', 'value': 'South Sudan', 'isoCode': 'SS'},
#     {'type': 'COUNTRY', 'value': 'Region: Gaza'},
#     {'type': 'ENTITY LISTING TYPE', 'value': 'SDN List'},
#     {'type': 'ENTITY LISTING TYPE',
#      'value': 'Non-SDN Palestinian Legislative Council List'},
#     {'type': 'ENTITY LISTING TYPE', 'value': 'FSE List'},
#     {'type': 'ENTITY LISTING TYPE',
#      'value': 'Sectoral Sanctions Identifications List'},
#     {'type': 'ENTITY LISTING TYPE', 'value': 'Consolidated List'},
#     {'type': 'ENTITY LISTING TYPE', 'value': 'CAPTA List'},
#     {'type': 'ENTITY LISTING TYPE',
#      'value': 'Non-SDN Menu-Based Sanctions List'},
#     {'type': 'ENTITY LISTING TYPE', 'value': 'Non-SDN CMIC List'},
#     {'type': 'Executive Order 13662 Directive Determination -',
#      'value': 'Subject to Directive 1'},
#     {'type': 'Executive Order 13662 Directive Determination -',
#      'value': 'Subject to Directive 2'},
#     {'type': 'Executive Order 13662 Directive Determination -',
#      'value': 'Subject to Directive 3'},
#     {'type': 'Executive Order 13662 Directive Determination -',
#      'value': 'Subject to Directive 4'},
#     {'type': 'Executive Order 13846 information:',
#      'value': 'EXCLUSION OF CORPORATE OFFICERS.  Sec. 4(e)'},
#     {'type': 'Executive Order 13846 information:',
#      'value': 'LOANS FROM UNITED STATES FINANCIAL INSTITUTIONS.  Sec. 5(a)(i)'},
#     {'type': 'Executive Order 13846 information:',
#      'value': 'FOREIGN EXCHANGE.  Sec. 5(a)(ii)'},
#     {'type': 'Executive Order 13846 information:',
#      'value': 'BANKING TRANSACTIONS.  Sec. 5(a)(iii)'},
#     {'type': 'Executive Order 13846 information:',
#      'value': 'BLOCKING PROPERTY AND INTERESTS IN PROPERTY.  Sec. 5(a)(iv)'},
#     {'type': 'Executive Order 13846 information:',
#      'value': 'BAN ON INVESTMENT IN EQUITY OR DEBT OF SANCTIONED PERSON.  Sec. 5(a)(v)'},
#     {'type': 'Executive Order 13846 information:',
#      'value': 'IMPORT SANCTIONS.  Sec. 5(a)(vi)'},
#     {'type': 'Executive Order 13846 information:',
#      'value': 'SANCTIONS ON PRINCIPAL EXECUTIVE OFFICERS. Sec. 5(a)(vii)'},
#     {'type': 'Executive Order 14014 Directive Information:',
#      'value': 'Subject to Directive 1 - As of the effective date, the provision, exportation, or reexportation, directly or indirectly, of financial services to or for the benefit of Myanma Oil and Gas Enterprise (MOGE) or its property or interests in property is prohibited.'},
#     {'type': 'Executive Order 14014 Directive Information:',
#      'value': 'For more information on directives, please visit the following link: https://ofac.treasury.gov/sanctions-programs-and-country-information/burma#directives'},
#     {'type': 'Executive Order 14024 Directive Information',
#      'value': "Subject to Directive 3 - All transactions in, provision of financing for, and other dealings in new debt of longer than 14 days maturity or new equity where such new debt or new equity is issued on or after the 'Effective Date (EO 14024 Directive)' associated with this name are prohibited."},
#     {'type': 'Executive Order 14024 Directive Information',
#      'value': 'Subject to Directive 1a - As of the effective date, participation in the secondary market for ruble or non-ruble denominated bonds issued on or after the effective date by the Central Bank of the Russian Federation, the National Wealth Fund of the Russian Federation, or the Ministry of Finance of the Russian Federation is prohibited.'},
#     {'type': 'Executive Order 14024 Directive Information',
#      'value': 'Subject to Directive 4 - any transaction involving the Central Bank of the Russian Federation, the National Wealth Fund of the Russian Federation, or the Ministry of Finance of the Russian Federation, including any transfer of assets to such entities or any foreign exchange transaction for or on behalf of such entities is prohibited.'},
#     {'type': 'Executive Order 14024 Directive Information -',
#      'value': 'For more information on directives, please visit the following link: https://home.treasury.gov/policy-issues/financial-sanctions/sanctions-programs-and-country-information/russian-harmful-foreign-activities-sanctions#directives'},
#     {'type': 'Executive Order 14059 information:',
#      'value': 'Prohibition on any United States financial institution from making loans or providing credit to this target'},
#     {'type': 'Executive Order 14059 information:',
#      'value': 'Prohibition on any transactions in foreign exchange that are subject to the jurisdiction of the United States and in which this target has any interest'},
#     {'type': 'Executive Order 14059 information:',
#      'value': 'Prohibition on any United States person from investing in or purchasing significant amounts of equity or debt instruments of this target'},
#     {'type': 'FEATURE DETAIL TYPE', 'value': 'DATE'},
#     {'type': 'FEATURE DETAIL TYPE', 'value': 'LOOKUP'},
#     {'type': 'FEATURE DETAIL TYPE', 'value': 'TEXT'},
#     {'type': 'FEATURE DETAIL TYPE', 'value': 'COUNTRY'},
#     {'type': 'Gender', 'value': 'Male'},
#     {'type': 'Gender', 'value': 'Female'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Cedula No.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Passport'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'SSN'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'R.F.C.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'D.N.I.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'NIT #'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'US FEIN'},
#     {'type': 'ID DOCUMENT TYPE', 'value': "Driver's License No."},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'RUC #'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'N.I.E.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'C.I.F.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Business Registration Document #'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'RIF #'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'National ID No.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Registration ID'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'LE Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Bosnian Personal ID No.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Registered Charity No.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'V.A.T. Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Credencial electoral'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Kenyan ID No.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Italian Fiscal Code'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Serial No.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'C.I.N.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'C.U.I.T.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Tax ID No.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Moroccan Personal ID No.'},
#     {'type': 'ID DOCUMENT TYPE',
#      'value': 'Public Security and Immigration No.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'C.U.R.P.'},
#     {'type': 'ID DOCUMENT TYPE',
#      'value': 'British National Overseas Passport'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'C.R. No.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'UK Company Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Immigration No.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Travel Document Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Electoral Registry No.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Identification Number'},
#     {'type': 'ID DOCUMENT TYPE',
#      'value': 'Paraguayan tax identification number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'National Foreign ID Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'RFC'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Diplomatic Passport'},
#     {'type': 'ID DOCUMENT TYPE',
#      'value': 'Dubai Chamber of Commerce Membership No.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Trade License No.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Commercial Registry Number'},
#     {'type': 'ID DOCUMENT TYPE',
#      'value': 'Certificate of Incorporation Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Tourism License No.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Aircraft Serial Identification'},
#     {'type': 'ID DOCUMENT TYPE',
#      'value': 'Cartilla de Servicio Militar Nacional'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'C.U.I.P.'},
#     {'type': 'ID DOCUMENT TYPE',
#      'value': 'Vessel Registration Identification'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Personal ID Card'},
#     {'type': 'ID DOCUMENT TYPE',
#      'value': 'Registration Certificate Number (Dubai)'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'VisaNumberID'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Matricula Mercantil No'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Residency Number'},
#     {'type': 'ID DOCUMENT TYPE',
#      'value': 'Numero Unico de Identificacao Tributaria (NUIT)'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'CNP (Personal Numerical Code)'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Romanian Permanent Resident'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Government Gazette Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Fiscal Code'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Pilot License Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Romanian C.R.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Folio Mercantil No.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Istanbul Chamber of Comm. No.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Turkish Identification Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Romanian Tax Registration'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Stateless Person Passport'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Stateless Person ID Card'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Refugee ID Card'},
#     {'type': 'ID DOCUMENT TYPE',
#      'value': 'Afghan Money Service Provider License Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'MMSI'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Company Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Public Registration Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'N.I.F.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'RTN'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Numero de Identidad'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'SRE Permit No.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Tazkira National ID Card'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'License'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Chinese Commercial Code'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'I.F.E.'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Branch Unit Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Enterprise Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Organization Code'},
#     {'type': 'ID DOCUMENT TYPE', 'value': "Citizen's Card Number"},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'UAE Identification'},
#     {'type': 'ID DOCUMENT TYPE',
#      'value': 'United Social Credit Code Certificate (USCCC)'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Chamber of Commerce Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Legal Entity Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Business Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Birth Certificate Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Business Registration Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Registration Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'MSB Registration Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'RSIN'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'File Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'C.U.I.'},
#     {'type': 'ID DOCUMENT TYPE',
#      'value': "Seafarer's Identification Document"},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Unified Social Credit Code (USCC)'},
#     {'type': 'ID DOCUMENT TYPE',
#      'value': 'Central Registration System Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Economic Register Number (CBLS)'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Trademark number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Permit Number'},
#     {'type': 'ID DOCUMENT TYPE', 'value': 'Military Registration Number'},
#     {'type': 'ID DOCUMENT TYPE',
#      'value': 'Russian State Individual Business Registration Number Pattern (OGRNIP)'},
#     {'type': 'IFCA Determination -', 'value': 'Involved in Energy Sector'},
#     {'type': 'IFCA Determination -',
#      'value': 'Involved in the Shipping Sector'},
#     {'type': 'IFCA Determination -', 'value': 'Port Operator'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13608 (Iran/Syria)',
#      'code': 'Executive Order 13608 (Iran/Syria)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13566 (Libya)',
#      'code': 'Executive Order 13566 (Libya)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13441 (Lebanon)',
#      'code': 'Executive Order 13441 (Lebanon)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13382 (Non-proliferation)',
#      'code': 'Executive Order 13382 (Non-proliferation)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 12947 (Terrorism)',
#      'code': 'Executive Order 12947 (Terrorism)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 12978 (Counter Narcotics SDNT)',
#      'code': 'Executive Order 12978 (Counter Narcotics SDNT)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 12854 (Cuba)',
#      'code': 'Executive Order 12854 (Cuba)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13413 (DRC)',
#      'code': 'Executive Order 13413 (DRC)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13606 (Iran/Syria)',
#      'code': 'Executive Order 13606 (Iran/Syria)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13599 (Iran)',
#      'code': 'Executive Order 13599 (Iran)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13224 (Terrorism)',
#      'code': 'Executive Order 13224 (Terrorism)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13553 (Iran)',
#      'code': 'Executive Order 13553 (Iran)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13304 (Balkans)',
#      'code': 'Executive Order 13304 (Balkans)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13405 (Belarus)',
#      'code': 'Executive Order 13405 (Belarus)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Foreign Narcotics Kingpin Designation Act',
#      'code': 'Foreign Narcotics Kingpin Designation Act'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13438 (Iraq)',
#      'code': 'Executive Order 13438 (Iraq)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13315 (Iraq)',
#      'code': 'Executive Order 13315 (Iraq)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13536 (Somalia)',
#      'code': 'Executive Order 13536 (Somalia)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13551 (North Korea)',
#      'code': 'Executive Order 13551 (North Korea)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13582 (Syria)',
#      'code': 'Executive Order 13582 (Syria)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13573 (Syria)',
#      'code': 'Executive Order 13573 (Syria)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13572 (Syria)',
#      'code': 'Executive Order 13572 (Syria)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13460 (Syria)',
#      'code': 'Executive Order 13460 (Syria)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13338 (Syria)',
#      'code': 'Executive Order 13338 (Syria)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13581 (TCO)',
#      'code': 'Executive Order 13581 (TCO)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13611 (Yemen)',
#      'code': 'Executive Order 13611 (Yemen)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13469 (Zimbabwe)',
#      'code': 'Executive Order 13469 (Zimbabwe)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13391 (Zimbabwe)',
#      'code': 'Executive Order 13391 (Zimbabwe)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'General License 4 Under EO 13224 (Terrorism)',
#      'code': 'General License 4 Under EO 13224 (Terrorism)'},
#     {'type': 'LEGAL AUTHORITY', 'value': 'CISADA', 'code': 'CISADA'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13628 (Iran)',
#      'code': 'Executive Order 13628 (Iran)'},
#     {'type': 'LEGAL AUTHORITY', 'value': 'TRA', 'code': 'TRA'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13628 - Section 3',
#      'code': 'Executive Order 13628 - Section 3'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13628 - Section 7',
#      'code': 'Executive Order 13628 - Section 7'},
#     {'type': 'LEGAL AUTHORITY', 'value': 'INA', 'code': 'INA'},
#     {'type': 'LEGAL AUTHORITY', 'value': 'Magnitsky', 'code': 'Magnitsky'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13620 (Somalia)',
#      'code': 'Executive Order 13620 (Somalia)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13660 (Ukraine)',
#      'code': 'Executive Order 13660 (Ukraine)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13664 (South Sudan)',
#      'code': 'Executive Order 13664 (South Sudan)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13661 (Ukraine)',
#      'code': 'Executive Order 13661 (Ukraine)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13667 (CAR)',
#      'code': 'Executive Order 13667 (CAR)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13662 (Ukraine)',
#      'code': 'Executive Order 13662 (Ukraine)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13726 (Libya)',
#      'code': 'Executive Order 13726 (Libya)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13687 (North Korea)',
#      'code': 'Executive Order 13687 (North Korea)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13685 (Ukraine)',
#      'code': 'Executive Order 13685 (Ukraine)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13692 (Venezuela)',
#      'code': 'Executive Order 13692 (Venezuela)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Cuban Assets Control Regulations (CACR)',
#      'code': 'Cuban Assets Control Regulations (CACR)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13694 (Cyber)',
#      'code': 'Executive Order 13694 (Cyber)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13722 (North Korea)',
#      'code': 'Executive Order 13722 (North Korea)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13757 (Cyber)',
#      'code': 'Executive Order 13757 (Cyber)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13810 (North Korea)',
#      'code': 'Executive Order 13810 (North Korea)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': '31 CFR 594.201(a)(5)',
#      'code': '31 CFR 594.201(a)(5)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13818 (Global Magnitsky)',
#      'code': 'Executive Order 13818 (Global Magnitsky)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'CAATSA - Section 224',
#      'code': 'CAATSA - Section 224'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'CAATSA - Section 231',
#      'code': 'CAATSA - Section 231'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'CAATSA - Section 228',
#      'code': 'CAATSA - Section 228'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13846 (Iran)',
#      'code': 'Executive Order 13846 (Iran)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13851 (Nicaragua)',
#      'code': 'Executive Order 13851 (Nicaragua)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13850 (Venezuela)',
#      'code': 'Executive Order 13850 (Venezuela)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13871 (Iran)',
#      'code': 'Executive Order 13871 (Iran)'},
#     {'type': 'LEGAL AUTHORITY', 'value': 'NHRAA', 'code': 'NHRAA'},
#     {'type': 'LEGAL AUTHORITY', 'value': 'NKSPEA', 'code': 'NKSPEA'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13876 (Iran)',
#      'code': 'Executive Order 13876 (Iran)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13882 (Mali)',
#      'code': 'Executive Order 13882 (Mali)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13848 (Election)',
#      'code': 'Executive Order 13848 (Election)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'HIFPAA - Title I',
#      'code': 'HIFPAA - Title I'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13846',
#      'code': 'Executive Order 13846'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13894 (Syria-related)',
#      'code': 'Executive Order 13894 (Syria-related)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13884 (Venezuela)',
#      'code': 'Executive Order 13884 (Venezuela)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13902 (Iran)',
#      'code': 'Executive Order 13902 (Iran)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 14059 (Illicit Drugs)',
#      'code': 'Executive Order 14059 (Illicit Drugs)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'CAATSA - Section 106',
#      'code': 'CAATSA - Section 106'},
#     {'type': 'LEGAL AUTHORITY', 'value': 'Caesar Act', 'code': 'Caesar Act'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 13936 (HK)',
#      'code': 'Executive Order 13936 (HK)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order - Convential Arms (Iran)',
#      'code': 'Executive Order - Convential Arms (Iran)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': '31 CFR 542.201(a)',
#      'code': '31 CFR 542.201(a)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Protecting Europe’s Energy Security Act (PEESA)',
#      'code': 'Protecting Europe’s Energy Security Act (PEESA)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'CAATSA - Section 232',
#      'code': 'CAATSA - Section 232'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 14014',
#      'code': 'Executive Order 14014'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order (Russia)',
#      'code': 'Executive Order (Russia)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 14024 (Russia)',
#      'code': 'Executive Order 14024 (Russia)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 14032 (CMIC)',
#      'code': 'Executive Order 14032 (CMIC)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 14039',
#      'code': 'Executive Order 14039'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 14038 (Belarus)',
#      'code': 'Executive Order 14038 (Belarus)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 14033 (Balkans)',
#      'code': 'Executive Order 14033 (Balkans)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 14046 (Ethiopia)',
#      'code': 'Executive Order 14046 (Ethiopia)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 14065',
#      'code': 'Executive Order 14065'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 14078 (Hostages)',
#      'code': 'Executive Order 14078 (Hostages)'},
#     {'type': 'LEGAL AUTHORITY', 'value': 'UHRPA', 'code': 'UHRPA'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 14098 (Sudan)',
#      'code': 'Executive Order 14098 (Sudan)'},
#     {'type': 'LEGAL AUTHORITY',
#      'value': 'Executive Order 14115 (West bank)',
#      'code': 'Executive Order 14115 (West bank)'},
#     {'type': 'LOCATION PART TYPE', 'value': 'REGION'},
#     {'type': 'LOCATION PART TYPE', 'value': 'ADDRESS1'},
#     {'type': 'LOCATION PART TYPE', 'value': 'ADDRESS2'},
#     {'type': 'LOCATION PART TYPE', 'value': 'ADDRESS3'},
#     {'type': 'LOCATION PART TYPE', 'value': 'CITY'},
#     {'type': 'LOCATION PART TYPE', 'value': 'STATE/PROVINCE'},
#     {'type': 'LOCATION PART TYPE', 'value': 'POSTAL CODE'},
#     {'type': 'NAME PART TYPE', 'value': 'Last Name'},
#     {'type': 'NAME PART TYPE', 'value': 'First Name'},
#     {'type': 'NAME PART TYPE', 'value': 'Middle Name'},
#     {'type': 'NAME PART TYPE', 'value': 'Maiden Name'},
#     {'type': 'NAME PART TYPE', 'value': 'Aircraft Name'},
#     {'type': 'NAME PART TYPE', 'value': 'Entity Name'},
#     {'type': 'NAME PART TYPE', 'value': 'Vessel Name'},
#     {'type': 'NAME PART TYPE', 'value': 'Nickname'},
#     {'type': 'NAME PART TYPE', 'value': 'Patronymic'},
#     {'type': 'NAME PART TYPE', 'value': 'Matronymic'},
#     {'type': 'Organization Type:',
#      'value': 'Growing of vegetables and melons, roots and tubers'},
#     {'type': 'Organization Type:',
#      'value': 'Growing of pome fruits and stone fruits'},
#     {'type': 'Organization Type:', 'value': 'Raising of sheep and goats'},
#     {'type': 'Organization Type:', 'value': 'Mixed farming'},
#     {'type': 'Organization Type:',
#      'value': 'Support activities for crop production'},
#     {'type': 'Organization Type:',
#      'value': 'Support activities for animal production'},
#     {'type': 'Organization Type:', 'value': 'Post-harvest crop activities'},
#     {'type': 'Organization Type:', 'value': 'Mining of hard coal'},
#     {'type': 'Organization Type:', 'value': 'Mining of lignite'},
#     {'type': 'Organization Type:', 'value': 'Extraction of crude petroleum'},
#     {'type': 'Organization Type:', 'value': 'Mining of iron ores'},
#     {'type': 'Organization Type:',
#      'value': 'Mining of other non-ferrous metal ores'},
#     {'type': 'Organization Type:',
#      'value': 'Support activities for petroleum and natural gas extraction'},
#     {'type': 'Organization Type:',
#      'value': 'Support activities for other mining and quarrying'},
#     {'type': 'Organization Type:',
#      'value': 'Manufacture of refined petroleum products'},
#     {'type': 'Organization Type:',
#      'value': 'Manufacture of pharmaceuticals, medicinal chemical and botanical products'},
#     {'type': 'Organization Type:',
#      'value': 'Manufacture of air and spacecraft and related machinery'},
#     {'type': 'Organization Type:', 'value': 'Construction of buildings'},
#     {'type': 'Organization Type:',
#      'value': 'Construction of roads and railways'},
#     {'type': 'Organization Type:',
#      'value': 'Construction of utility projects'},
#     {'type': 'Organization Type:',
#      'value': 'Construction of other civil engineering projects'},
#     {'type': 'Organization Type:',
#      'value': 'Sea and coastal freight water transport'},
#     {'type': 'Organization Type:',
#      'value': 'Inland passenger water transport'},
#     {'type': 'Organization Type:', 'value': 'Inland freight water transport'},
#     {'type': 'Organization Type:', 'value': 'Passenger air transport'},
#     {'type': 'Organization Type:', 'value': 'Freight air transport'},
#     {'type': 'Organization Type:',
#      'value': 'Short term accommodation activities'},
#     {'type': 'Organization Type:',
#      'value': 'Restaurants and mobile food service activities'},
#     {'type': 'Organization Type:',
#      'value': 'Wired telecommunications activities'},
#     {'type': 'Organization Type:',
#      'value': 'Wireless telecommunications activities'},
#     {'type': 'Organization Type:', 'value': 'Central banking'},
#     {'type': 'Organization Type:', 'value': 'Activities of holding companies'},
#     {'type': 'Organization Type:',
#      'value': 'Trusts, funds and similar financial entities'},
#     {'type': 'Organization Type:', 'value': 'Financial leasing'},
#     {'type': 'Organization Type:',
#      'value': 'Real estate activities with own or leased property'},
#     {'type': 'Organization Type:',
#      'value': 'Real estate activities on a fee or contract basis'},
#     {'type': 'Organization Type:', 'value': 'Advertising'},
#     {'type': 'Organization Type:', 'value': 'Travel agency activities'},
#     {'type': 'Organization Type:', 'value': 'Tour operator activities'},
#     {'type': 'Organization Type:', 'value': 'Operation of sports facilities'},
#     {'type': 'Organization Type:', 'value': 'Activities of sports clubs'},
#     {'type': 'Organization Type:', 'value': 'Manufacture of furniture'},
#     {'type': 'Organization Type:',
#      'value': 'Sale of motor vehicle parts and accessories'},
#     {'type': 'Organization Type:',
#      'value': 'Wholesale of food, beverages and tobacco'},
#     {'type': 'Organization Type:',
#      'value': 'Wholesale of electronic and telecommunications equipment and parts'},
#     {'type': 'Organization Type:',
#      'value': 'Wholesale of metals and metal ores'},
#     {'type': 'Organization Type:',
#      'value': 'Wholesale of construction materials, hardware, plumbing and heating equipment and supplies'},
#     {'type': 'Organization Type:', 'value': 'Postal activities'},
#     {'type': 'Organization Type:', 'value': 'Private security activities'},
#     {'type': 'Organization Type:',
#      'value': 'Other financial service activities, except insurance and pension funding activities, n.e.c.'},
#     {'type': 'Organization Type:',
#      'value': 'Manufacture of articles of concrete, cement and plaster'},
#     {'type': 'Organization Type:',
#      'value': 'Manufacture of plastics products'},
#     {'type': 'Organization Type:', 'value': 'Higher education'},
#     {'type': 'Organization Type:',
#      'value': 'Manufacture of medical and dental instruments and supplies'},
#     {'type': 'Organization Type:',
#      'value': 'Other telecommunications activities'},
#     {'type': 'Organization Type:',
#      'value': 'Wholesale of other machinery and equipment'},
#     {'type': 'Organization Type:',
#      'value': 'General public administration activities'},
#     {'type': 'Organization Type:',
#      'value': 'Motion picture, video and television programme production activities'},
#     {'type': 'Organization Type:',
#      'value': 'Publishing of newspapers, journals and periodicals'},
#     {'type': 'Organization Type:', 'value': 'News agency activities'},
#     {'type': 'Organization Type:', 'value': 'Other monetary intermediation'},
#     {'type': 'Organization Type:',
#      'value': 'Activities of political organizations'},
#     {'type': 'Organization Type:',
#      'value': 'Public order and safety activities'},
#     {'type': 'Organization Type:',
#      'value': 'Wholesale of other household goods'},
#     {'type': 'Organization Type:',
#      'value': 'Other information technology and computer service activities'},
#     {'type': 'Organization Type:',
#      'value': 'Manufacture of jewellery and related articles'},
#     {'type': 'Organization Type:',
#      'value': 'Other business support service activities n.e.c.'},
#     {'type': 'Organization Type:',
#      'value': 'Manufacture of basic precious and other non-ferrous metals'},
#     {'type': 'Organization Type:', 'value': 'Sale of motor vehicles'},
#     {'type': 'Organization Type:',
#      'value': 'Processing and preserving of fish, crustaceans and molluscs'},
#     {'type': 'Organization Type:',
#      'value': 'Manufacture of other food products n.e.c.'},
#     {'type': 'Organization Type:',
#      'value': 'Maintenance and repair of motor vehicles'},
#     {'type': 'Organization Type:',
#      'value': 'Management consultancy activities'},
#     {'type': 'Organization Type:', 'value': 'Other human health activities'},
#     {'type': 'Organization Type:',
#      'value': 'Other amusement and recreation activities'},
#     {'type': 'Organization Type:',
#      'value': 'Accounting, bookkeeping and auditing activities; tax consultancy'},
#     {'type': 'Organization Type:', 'value': 'Non-specialized wholesale trade'},
#     {'type': 'Organization Type:',
#      'value': 'Service activities incidental to air transportation'},
#     {'type': 'Organization Type:', 'value': 'Marine Fishing'},
#     {'type': 'Organization Type:',
#      'value': 'Other transportation support activities'},
#     {'type': 'Organization Type:',
#      'value': 'Other reservation service and related activities'},
#     {'type': 'Organization Type:', 'value': 'Mining and Quarrying'},
#     {'type': 'Organization Type:',
#      'value': 'Research and experimental development on natural sciences and engineering'},
#     {'type': 'Organization Type:', 'value': 'Defense activities'},
#     {'type': 'Organization Type:',
#      'value': 'Retail sale of pharmaceutical and medical goods, cosmetic and toilet articles in specialized stores'},
#     {'type': 'Organization Type:',
#      'value': 'Hairdressing and other beauty treatment'},
#     {'type': 'Organization Type:',
#      'value': 'Wholesale of solid, liquid and gaseous fuels and related products'},
#     {'type': 'Organization Type:', 'value': 'Transportation and storage'},
#     {'type': 'Organization Type:',
#      'value': 'Manufacture of chemicals and chemical products'},
#     {'type': 'Organization Type:',
#      'value': 'Wholesale of jewelry, watches, precious stones, and precious metals'},
#     {'type': 'Organization Type:',
#      'value': 'Chemicals and allied products wholesale'},
#     {'type': 'Organization Type:',
#      'value': 'Retail sale of textiles in specialized stores'},
#     {'type': 'Organization Type:', 'value': 'Sports and recreation education'},
#     {'type': 'Organization Type:',
#      'value': 'Retail sale via mail order houses or via Internet'},
#     {'type': 'Organization Type:',
#      'value': 'Manufacture of other porcelain and ceramic products'},
#     {'type': 'Organization Type:', 'value': 'Packaging activities'},
#     {'type': 'Organization Type:',
#      'value': 'Cutting, shaping and finishing of stone'},
#     {'type': 'Organization Type:', 'value': 'Logging'},
#     {'type': 'Organization Type:',
#      'value': 'Retail sale of information and communications equipment in specialized stores'},
#     {'type': 'Organization Type:', 'value': 'Computer programming activities'},
#     {'type': 'Organization Type:',
#      'value': 'Retail sale of clothing, footwear and leather articles in specialized stores'},
#     {'type': 'Organization Type:',
#      'value': 'Manufacture of other fabricated metal products n.e.c.'},
#     {'type': 'Organization Type:',
#      'value': 'Manufacture of other special-purpose machinery'},
#     {'type': 'Organization Type:',
#      'value': 'Manufacture of pulp, paper and paperboard'},
#     {'type': 'Organization Type:',
# ...
#         'translations': {'translation': {'isPrimary': 'true',
#           'script': 'Latin',
#           'formattedLastName': 'AIR FORCE, IRGC (PASDARAN)',
#           'formattedFullName': 'AIR FORCE, IRGC (PASDARAN)',
#           'nameParts': {'namePart': {'type': 'Entity Name',
#             'value': 'Air Force, IRGC (Pasdaran)'}}}}},
#        {'isPrimary': 'false',
#         'aliasType': 'A.K.A.',
#         'isLowQuality': 'false',
#         'translations': {'translation': {'isPrimary': 'true',
#           'script': 'Latin',
#           'formattedLastName': 'ISLAMIC REVOLUTIONARY GUARDS CORPS AEROSPACE FORCE',
#           'formattedFullName': 'ISLAMIC REVOLUTIONARY GUARDS CORPS AEROSPACE FORCE',
#           'nameParts': {'namePart': {'type': 'Entity Name',
#             'value': 'ISLAMIC REVOLUTIONARY GUARDS CORPS AEROSPACE FORCE'}}}}},
#        {'isPrimary': 'false',
#         'aliasType': 'A.K.A.',
#         'isLowQuality': 'false',
#         'translations': {'translation': {'isPrimary': 'true',
#           'script': 'Latin',
#           'formattedLastName': 'AEROSPACE FORCE OF THE ARMY OF THE GUARDIANS OF THE ISLAMIC REVOLUTION',
#           'formattedFullName': 'AEROSPACE FORCE OF THE ARMY OF THE GUARDIANS OF THE ISLAMIC REVOLUTION',
#           'nameParts': {'namePart': {'type': 'Entity Name',
#             'value': 'Aerospace Force of the Army of the Guardians of the Islamic Revolution'}}}}},
#        {'isPrimary': 'false',
#         'aliasType': 'A.K.A.',
#         'isLowQuality': 'false',
#         'translations': {'translation': {'isPrimary': 'true',
#           'script': 'Latin',
#           'formattedLastName': 'AFAGIR',
#           'formattedFullName': 'AFAGIR',
#           'nameParts': {'namePart': {'type': 'Entity Name',
#             'value': 'AFAGIR'}}}}},
#        {'isPrimary': 'false',
#         'aliasType': 'A.K.A.',
#         'isLowQuality': 'false',
#         'translations': {'translation': {'isPrimary': 'true',
#           'script': 'Latin',
#           'formattedLastName': 'AEROSPACE DIVISION OF IRGC',
#           'formattedFullName': 'AEROSPACE DIVISION OF IRGC',
#           'nameParts': {'namePart': {'type': 'Entity Name',
#             'value': 'Aerospace Division of IRGC'}}}}},
#        {'isPrimary': 'false',
#         'aliasType': 'A.K.A.',
#         'isLowQuality': 'false',
#         'translations': {'translation': {'isPrimary': 'true',
#           'script': 'Latin',
#           'formattedLastName': 'IRGC AEROSPACE FORCE',
#           'formattedFullName': 'IRGC AEROSPACE FORCE',
#           'nameParts': {'namePart': {'type': 'Entity Name',
#             'value': 'IRGC Aerospace Force'}}}}},
#        {'isPrimary': 'false',
#         'aliasType': 'A.K.A.',
#         'isLowQuality': 'false',
#         'translations': {'translation': {'isPrimary': 'true',
#           'script': 'Latin',
#           'formattedLastName': 'IRGCASF',
#           'formattedFullName': 'IRGCASF',
#           'nameParts': {'namePart': {'type': 'Entity Name',
#             'value': 'IRGCASF'}}}}}]},
#      'addresses': {'address': [{'country': 'Iran',
#         'translations': {'translation': {'isPrimary': 'true',
#           'script': 'Latin',
#           'addressParts': {'addressPart': {'type': 'CITY',
#             'value': 'Tehran'}}}}},
#        {'country': 'Syria',
#         'translations': {'translation': {'isPrimary': 'true',
#           'script': 'Latin'}}}]},
#      'features': {'feature': [{'type': 'Additional Sanctions Information -',
#         'versionId': '12085',
#         'value': 'Subject to Secondary Sanctions',
#         'valueRefId': '91473',
#         'isPrimary': 'true',
#         'reliability': 'Confirmed'},
#        {'type': 'Secondary sanctions risk:',
#         'versionId': '71480',
#         'value': 'See Section 11 of Executive Order 14024.',
#         'valueRefId': '92764',
#         'isPrimary': 'true'}]}},
#     {'generalInfo': {'identityId': '32226',
#       'entityType': 'Individual',
#       'title': 'Commander of Najaf Ashraf West Headquarters; Brigadier General'},
#      'sanctionsLists': {'sanctionsList': 'SDN List'},
#      'sanctionsPrograms': {'sanctionsProgram': ['IRAN-HR',
#        'IRGC',
#        'CAATSA - IRAN']},
#      'sanctionsTypes': {'sanctionsType': 'Block'},
#      'legalAuthorities': {'legalAuthority': 'Executive Order 13553 (Iran)'},
#      'names': {'name': [{'isPrimary': 'true',
#         'isLowQuality': 'false',
#         'translations': {'translation': [{'isPrimary': 'true',
#            'script': 'Latin',
#            'formattedFirstName': 'Mohammad Nazar',
#            'formattedLastName': 'AZIMI',
#            'formattedFullName': 'AZIMI, Mohammad Nazar',
#            'nameParts': {'namePart': [{'type': 'Last Name', 'value': 'AZIMI'},
#              {'type': 'First Name', 'value': 'Mohammad'},
#              {'type': 'Middle Name', 'value': 'Nazar'}]}},
#           {'isPrimary': 'false',
#            'script': 'Arabic',
#            'formattedLastName': '\u202bمحمد نظر عظیمی\u202c',
#            'formattedFullName': '\u202bمحمد نظر عظیمی\u202c',
#            'nameParts': {'namePart': [{'type': 'Last Name', 'value': 'عظیمی'},
#              {'type': 'First Name', 'value': 'محمد'},
#              {'type': 'Middle Name', 'value': 'نظر'}]}}]}},
#        {'isPrimary': 'false',
#         'aliasType': 'A.K.A.',
#         'isLowQuality': 'false',
#         'translations': {'translation': [{'isPrimary': 'true',
#            'script': 'Latin',
#            'formattedFirstName': 'Mohammad',
#            'formattedLastName': 'AZIMI',
#            'formattedFullName': 'AZIMI, Mohammad',
#            'nameParts': {'namePart': [{'type': 'Last Name', 'value': 'AZIMI'},
#              {'type': 'First Name', 'value': 'Mohammad'}]}},
#           {'isPrimary': 'false',
#            'script': 'Arabic',
#            'formattedLastName': '\u202bمحمد عظیمی\u202c',
#            'formattedFullName': '\u202bمحمد عظیمی\u202c',
#            'nameParts': {'namePart': [{'type': 'Last Name', 'value': 'عظیمی'},
#              {'type': 'First Name', 'value': 'محمد'}]}}]}}]},
#      'addresses': {'address': {'country': 'Iran',
#        'translations': {'translation': {'isPrimary': 'true',
#          'script': 'Latin'}}}},
#      'features': {'feature': [{'type': 'Birthdate',
#         'versionId': '55567',
#         'value': '21 Mar 1960',
#         'valueDate': {'fromDateBegin': '1960-03-21',
#          'fromDateEnd': '1960-03-21',
#          'toDateBegin': '1960-03-21',
#          'toDateEnd': '1960-03-21',
#          'isApproximate': 'false',
#          'isDateRange': 'false'},
#         'isPrimary': 'true'},
#        {'type': 'Place of Birth',
#         'versionId': '55568',
#         'value': 'Kangavar, Iran',
#         'isPrimary': 'true'},
#        {'type': 'Additional Sanctions Information -',
#         'versionId': '55571',
#         'value': 'Subject to Secondary Sanctions',
#         'valueRefId': '91473',
#         'isPrimary': 'true'},
#        {'type': 'Nationality Country',
#         'versionId': '55573',
#         'value': 'Iran',
#         'valueRefId': '11109',
#         'isPrimary': 'true'},
#        {'type': 'Gender',
#         'versionId': '55574',
#         'value': 'Male',
#         'valueRefId': '91526',
#         'isPrimary': 'true'}]},
#      'identityDocuments': {'identityDocument': {'type': 'National ID No.',
#        'name': 'AZIMI, Mohammad Nazar',
#        'documentNumber': '3309730409',
#        'isValid': 'true',
#        'issuingCountry': 'Iran'}},
#      'relationships': {'relationship': {'type': 'Acting for or on behalf of',
#        'relatedEntity': 'ISLAMIC REVOLUTIONARY GUARD CORPS'}}},
#     {'generalInfo': {'identityId': '32225',
#       'entityType': 'Individual',
#       'title': 'Deputy Commander of IRGC West Regional Headquarters (Najaf Ashraf); Second Brigadier General'},
#      'sanctionsLists': {'sanctionsList': 'SDN List'},
#      'sanctionsPrograms': {'sanctionsProgram': ['IRAN-HR',
#        'IRGC',
#        'CAATSA - IRAN']},
#      'sanctionsTypes': {'sanctionsType': 'Block'},
#      'legalAuthorities': {'legalAuthority': 'Executive Order 13553 (Iran)'},
#      'names': {'name': [{'isPrimary': 'true',
#         'isLowQuality': 'false',
#         'translations': {'translation': [{'isPrimary': 'true',
#            'script': 'Latin',
#            'formattedFirstName': 'Kourosh',
#            'formattedLastName': 'ASIABANI',
#            'formattedFullName': 'ASIABANI, Kourosh',
#            'nameParts': {'namePart': [{'type': 'Last Name',
#               'value': 'ASIABANI'},
#              {'type': 'First Name', 'value': 'Kourosh'}]}},
#           {'isPrimary': 'false',
#            'script': 'Arabic',
#            'formattedLastName': '\u202bکورش آسیابانی\u202c',
#            'formattedFullName': '\u202bکورش آسیابانی\u202c',
#            'nameParts': {'namePart': [{'type': 'Last Name',
#               'value': 'آسیابانی'},
#              {'type': 'First Name', 'value': 'کورش'}]}}]}},
#        {'isPrimary': 'false',
#         'aliasType': 'A.K.A.',
#         'isLowQuality': 'false',
#         'translations': {'translation': [{'isPrimary': 'true',
#            'script': 'Latin',
#            'formattedFirstName': 'Kurosh',
#            'formattedLastName': 'ASIABANI',
#            'formattedFullName': 'ASIABANI, Kurosh',
#            'nameParts': {'namePart': [{'type': 'Last Name',
#               'value': 'ASIABANI'},
#              {'type': 'First Name', 'value': 'Kurosh'}]}},
#           {'isPrimary': 'false',
#            'script': 'Arabic',
#            'formattedLastName': '\u202bکوروش آسیابانی\u202c',
#            'formattedFullName': '\u202bکوروش آسیابانی\u202c',
#            'nameParts': {'namePart': [{'type': 'Last Name',
#               'value': 'آسیابانی'},
#              {'type': 'First Name', 'value': 'کوروش'}]}}]}},
#        {'isPrimary': 'false',
#         'aliasType': 'A.K.A.',
#         'isLowQuality': 'false',
#         'translations': {'translation': {'isPrimary': 'true',
#           'script': 'Latin',
#           'formattedFirstName': 'Korosh',
#           'formattedLastName': 'ASIABANI',
#           'formattedFullName': 'ASIABANI, Korosh',
#           'nameParts': {'namePart': [{'type': 'Last Name',
#              'value': 'ASIABANI'},
#             {'type': 'First Name', 'value': 'Korosh'}]}}}},
#        {'isPrimary': 'false',
#         'aliasType': 'A.K.A.',
#         'isLowQuality': 'false',
#         'translations': {'translation': {'isPrimary': 'true',
#           'script': 'Latin',
#           'formattedFirstName': 'Koresh',
#           'formattedLastName': 'ASIYABANI',
#           'formattedFullName': 'ASIYABANI, Koresh',
#           'nameParts': {'namePart': [{'type': 'Last Name',
#              'value': 'ASIYABANI'},
#             {'type': 'First Name', 'value': 'Koresh'}]}}}}]},
#      'addresses': {'address': [{'country': 'Iran',
#         'translations': {'translation': {'isPrimary': 'true',
#           'script': 'Latin',
#           'addressParts': {'addressPart': [{'type': 'ADDRESS1',
#              'value': 'Number 0, Floor 2'},
#             {'type': 'ADDRESS2', 'value': 'Golrizan Boulevard, Fajr Alley'},
#             {'type': 'ADDRESS3', 'value': 'District 22 Bahman'},
#             {'type': 'CITY', 'value': 'Kermanshah'},
#             {'type': 'POSTAL CODE', 'value': '6714699785'}]}}}},
#        {'country': 'Iran',
#         'translations': {'translation': {'isPrimary': 'true',
#           'script': 'Latin',
#           'addressParts': {'addressPart': [{'type': 'ADDRESS1',
#              'value': 'Unit 1, Paradise Building, across from Kokab Rashidi Mosque'},
#             {'type': 'ADDRESS2',
#              'value': 'Nobehar Boulevard, between Shahid Iraj Faizi Alley and Shahid Khosro Abassi Alley'},
#             {'type': 'ADDRESS3', 'value': 'District 22 Bahman'},
#             {'type': 'CITY', 'value': 'Kermanshah'},
#             {'type': 'POSTAL CODE', 'value': '6714699785'}]}}}}]},
#      'features': {'feature': [{'type': 'Birthdate',
#         'versionId': '55562',
#         'value': '31 May 1962',
#         'valueDate': {'fromDateBegin': '1962-05-31',
#          'fromDateEnd': '1962-05-31',
#          'toDateBegin': '1962-05-31',
#          'toDateEnd': '1962-05-31',
#          'isApproximate': 'false',
#          'isDateRange': 'false'},
#         'isPrimary': 'true'},
#        {'type': 'Birthdate',
#         'versionId': '55563',
#         'value': '31 May 1961',
#         'valueDate': {'fromDateBegin': '1961-05-31',
#          'fromDateEnd': '1961-05-31',
#          'toDateBegin': '1961-05-31',
#          'toDateEnd': '1961-05-31',
#          'isApproximate': 'false',
#          'isDateRange': 'false'},
#         'isPrimary': 'false'},
#        {'type': 'Place of Birth',
#         'versionId': '55564',
#         'value': 'Harsin, Iran',
#         'isPrimary': 'true'},
#        {'type': 'Nationality Country',
#         'versionId': '55565',
#         'value': 'Iran',
#         'valueRefId': '11109',
#         'isPrimary': 'true'},
#        {'type': 'Gender',
#         'versionId': '55566',
#         'value': 'Male',
#         'valueRefId': '91526',
#         'isPrimary': 'true'},
#        {'type': 'Additional Sanctions Information -',
#         'versionId': '55575',
#         'value': 'Subject to Secondary Sanctions',
#         'valueRefId': '91473',
#         'isPrimary': 'true'}]},
#      'identityDocuments': {'identityDocument': [{'type': 'National ID No.',
#         'name': 'ASIABANI, Kourosh',
#         'documentNumber': '3319728962',
#         'isValid': 'true',
#         'issuingCountry': 'Iran'},
#        {'type': 'Birth Certificate Number',
#         'name': 'ASIABANI, Kourosh',
#         'documentNumber': '28',
#         'isValid': 'true',
#         'issuingCountry': 'Iran'}]},
#      'relationships': {'relationship': {'type': 'Acting for or on behalf of',
#        'relatedEntity': 'ISLAMIC REVOLUTIONARY GUARD CORPS'}}},
#     {'generalInfo': {'identityId': '20608', 'entityType': 'Individual'},
#      'sanctionsLists': {'sanctionsList': 'SDN List'},
#      'sanctionsPrograms': {'sanctionsProgram': ['IRAN-HR',
#        'IRGC',
#        'IFSR',
#        'CAATSA - IRAN']},
#      'sanctionsTypes': {'sanctionsType': 'Block'},
#      'legalAuthorities': {'legalAuthority': ['Executive Order 13553 (Iran)',
#        'CISADA']},
#      'names': {'name': [{'isPrimary': 'true',
#         'isLowQuality': 'false',
#         'translations': {'translation': {'isPrimary': 'true',
#           'script': 'Latin',
#           'formattedFirstName': 'Hassan',
#           'formattedLastName': 'SHAHVARPOUR NAJAFABADI',
#           'formattedFullName': 'SHAHVARPOUR NAJAFABADI, Hassan',
#           'nameParts': {'namePart': [{'type': 'Last Name',
#              'value': 'SHAHVARPOUR NAJAFABADI'},
#             {'type': 'First Name', 'value': 'Hassan'}]}}}},
#        {'isPrimary': 'false',
#         'aliasType': 'A.K.A.',
#         'isLowQuality': 'false',
#         'translations': {'translation': {'isPrimary': 'true',
#           'script': 'Latin',
#           'formattedFirstName': 'Hassan',
#           'formattedLastName': 'SHAHVARPOUR',
#           'formattedFullName': 'SHAHVARPOUR, Hassan',
#           'nameParts': {'namePart': [{'type': 'Last Name',
#              'value': 'SHAHVARPOUR'},
#             {'type': 'First Name', 'value': 'Hassan'}]}}}}]},
#      'addresses': {'address': {'country': 'Iran',
#        'translations': {'translation': {'isPrimary': 'true',
#          'script': 'Latin'}}}},
#      'features': {'feature': [{'type': 'Place of Birth',
#         'versionId': '33191',
#         'value': 'Safi Abad, Dezful, Khuzestan, Iran',
#         'isPrimary': 'true'},
#        {'type': 'Nationality Country',
#         'versionId': '33192',
#         'value': 'Iran',
#         'valueRefId': '11109',
#         'isPrimary': 'true'},
#        {'type': 'Gender',
#         'versionId': '33193',
#         'value': 'Male',
#         'valueRefId': '91526',
#         'isPrimary': 'true'},
#        {'type': 'Additional Sanctions Information -',
#         'versionId': '33207',
#         'value': 'Subject to Secondary Sanctions',
#         'valueRefId': '91473',
#         'isPrimary': 'true'}]},
#      'identityDocuments': {'identityDocument': {'type': 'National ID No.',
#        'name': 'SHAHVARPOUR NAJAFABADI, Hassan',
#        'documentNumber': '2001624001',
#        'isValid': 'true',
#        'issuingCountry': 'Iran'}},
#      'relationships': {'relationship': {'type': 'Acting for or on behalf of',
#        'relatedEntity': 'ISLAMIC REVOLUTIONARY GUARD CORPS'}}}]}}}

# %% [markdown]
# ## Save as JSON

# %%
import json

output_file_name = "IRGC_sanctions.json"

json_content = json.dumps(xml_dict, indent=4)

with open(output_file_name, 'w') as json_file:
    json_file.write(json_content)
