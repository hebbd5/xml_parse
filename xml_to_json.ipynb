# %%
xml_data = ""
xml_filepath = "consolidated.xml"

with open(xml_filepath, "r") as file:
    xml_data = file.read()
    
print(type(xml_data))
print(len(xml_data))
# Out:
# <class 'str'>
# 919037

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(xml_data, features='xml')

def xml_to_dict(element):
    if isinstance(element, str):
        return element
    if not element.contents:
        return element.string
    result = {}
    for child in element.children:
        if isinstance(child, str):
            continue
        if child.name not in result:
            result[child.name] = xml_to_dict(child)
        else:
            if not isinstance(result[child.name], list):
                result[child.name] = [result[child.name]]
            result[child.name].append(xml_to_dict(child))
    # Directly capture text nodes without 'text' key
    if element.string and element.string.strip():
        return element.string.strip()
    return result

xml_dict = xml_to_dict(soup)

# %%
xml_dict
# Out:
# {'sdnList': {'publshInformation': {'Publish_Date': '05/06/2024',
#    'Record_Count': '443'},
#   'sdnEntry': [{'uid': '9639',
#     'firstName': 'Ismail Abdul Salah',
#     'lastName': 'HANIYA',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': [{'uid': '9150',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'HANIYA',
#        'firstName': 'Ismail'},
#       {'uid': '9151',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'HANIYYA',
#        'firstName': 'Ismaeel'}]},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4696',
#       'dateOfBirth': '1962',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '4697',
#       'placeOfBirth': 'Shati',
#       'mainEntry': 'true'}}},
#    {'uid': '9640',
#     'firstName': 'Mohammed',
#     'lastName': 'ABU TEIR',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': [{'uid': '9152',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'ABU TAIR',
#        'firstName': 'Mohammed Mahmud'},
#       {'uid': '9153',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'ABOU TAYR',
#        'firstName': 'Mohammad Mahmoud'}]},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4698',
#       'dateOfBirth': '1951',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '4699',
#       'placeOfBirth': 'Umm Tuba',
#       'mainEntry': 'true'}}},
#    {'uid': '9641',
#     'firstName': 'Jamileh Abdullah',
#     'lastName': 'AL-SHANTI',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': [{'uid': '9154',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'EL-SHANTI',
#        'firstName': 'Jameela Abdallah'},
#       {'uid': '9155',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'AL SHANTEE',
#        'firstName': 'Jamila Abed Allah'}]},
#     'addressList': {'address': {'uid': '12128',
#       'stateOrProvince': 'Gaza',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4700',
#       'dateOfBirth': '1955',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '4701',
#       'placeOfBirth': 'Jabalia Camp',
#       'mainEntry': 'true'}}},
#    {'uid': '9642',
#     'firstName': 'Mohammed Jamal',
#     'lastName': "NU'MAN ALAEDDIN",
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': [{'uid': '9156',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'ALA AL DIN',
#        'firstName': 'Mohamad Nouman'},
#       {'uid': '9157',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'AL NATSHEH',
#        'firstName': 'Mohammed'}]},
#     'addressList': {'address': {'uid': '12129',
#       'city': 'Hebron',
#       'stateOrProvince': 'West Bank',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4702',
#       'dateOfBirth': '1959',
#       'mainEntry': 'true'}}},
#    {'uid': '9643',
#     'firstName': 'Yasser Daoud',
#     'lastName': 'MANSOUR',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4703',
#       'dateOfBirth': '1967',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '4704',
#       'placeOfBirth': 'Nablus, West Bank',
#       'mainEntry': 'true'}}},
#    {'uid': '9644',
#     'firstName': 'Khalil Musa',
#     'lastName': 'RABAI',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9158',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'RABBAI',
#       'firstName': 'Khalil Mussa'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4705',
#       'dateOfBirth': '1959',
#       'mainEntry': 'true'}}},
#    {'uid': '9645',
#     'firstName': 'Huda Naim',
#     'lastName': 'AL-QREINAWI',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9159',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'AL QRENAWI',
#       'firstName': 'Houda Naim'}},
#     'addressList': {'address': {'uid': '12130',
#       'stateOrProvince': 'Gaza',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4706',
#       'dateOfBirth': '1969',
#       'mainEntry': 'true'}}},
#    {'uid': '9646',
#     'firstName': 'Mahmoud Ahmad',
#     'lastName': 'AL-RAMAHI',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'addressList': {'address': {'uid': '12131',
#       'city': 'Ramallah',
#       'stateOrProvince': 'West Bank',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4707',
#       'dateOfBirth': '1963',
#       'mainEntry': 'true'}}},
#    {'uid': '9647',
#     'firstName': 'Mahmoud Khaled',
#     'lastName': 'ZAHHAR',
#     'sdnType': 'Individual',
#     'remarks': '(Linked To: HAMAS)',
#     'programList': {'program': ['NS-PLC', 'SDGT']},
#     'idList': {'id': [{'uid': '166816',
#        'idType': 'Gender',
#        'idNumber': 'Male'},
#       {'uid': '166818',
#        'idType': 'Secondary sanctions risk:',
#        'idNumber': 'section 1(b) of Executive Order 13224, as amended by Executive Order 13886'}]},
#     'akaList': {'aka': [{'uid': '9160',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'AL ZAHAR',
#        'firstName': 'Mahmoud Khaled'},
#       {'uid': '71276',
#        'type': 'a.k.a.',
#        'category': 'weak',
#        'lastName': 'ZAHAR, Mahmoud'},
#       {'uid': '71277',
#        'type': 'a.k.a.',
#        'category': 'weak',
#        'lastName': 'AL-ZAHAR, Mahmoud'}]},
#     'addressList': {'address': {'uid': '68713', 'country': 'Region: Gaza'}},
#     'nationalityList': {'nationality': {'uid': '66817',
#       'country': 'Palestinian',
#       'mainEntry': 'true'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4708',
#       'dateOfBirth': '1945',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '66815',
#       'placeOfBirth': 'Gaza Strip',
#       'mainEntry': 'true'}}},
#    {'uid': '9648',
#     'firstName': 'Abdul Fattah',
#     'lastName': 'HASAN DUKHAN',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9161',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'HASAN DOUKHAN',
#       'firstName': 'Abdul Fattah'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4709',
#       'dateOfBirth': '1936',
#       'mainEntry': 'true'}}},
#    {'uid': '9649',
#     'firstName': 'Ibrahim Mohammed',
#     'lastName': 'DAHBOUR',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'addressList': {'address': {'uid': '12132',
#       'city': 'Jenin',
#       'stateOrProvince': 'West Bank',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4710',
#       'dateOfBirth': '1968',
#       'mainEntry': 'true'}}},
#    {'uid': '9650',
#     'firstName': 'Mariam Mahmoud',
#     'lastName': 'SALEH',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'addressList': {'address': {'uid': '12133',
#       'city': 'Ramallah',
#       'stateOrProvince': 'West Bank',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4711',
#       'dateOfBirth': '1952',
#       'mainEntry': 'true'}}},
#    {'uid': '9651',
#     'firstName': 'Fathi Mohammed',
#     'lastName': "QAR'AWI",
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9162',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'QARAWI',
#       'firstName': 'Mohammed Fathi'}},
#     'addressList': {'address': {'uid': '12134',
#       'city': 'Tulkarim',
#       'stateOrProvince': 'West Bank',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4712',
#       'dateOfBirth': '1958',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '4713',
#       'placeOfBirth': 'Ramin, West Bank',
#       'mainEntry': 'true'}}},
#    {'uid': '9652',
#     'firstName': 'Anwar Mohammed',
#     'lastName': 'ZBOUN',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9163',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'AL-ZBOUN',
#       'firstName': 'Anwar Muhammad'}},
#     'addressList': {'address': {'uid': '12135',
#       'city': 'Bethlehem',
#       'stateOrProvince': 'West Bank',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4714',
#       'dateOfBirth': '1968',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '4715',
#       'placeOfBirth': 'Ilar',
#       'mainEntry': 'true'}}},
#    {'uid': '9653',
#     'firstName': 'Imad Mahmoud',
#     'lastName': 'NOFAL',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9164',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'NAWFAL',
#       'firstName': 'Imad Mahmoud'}},
#     'addressList': {'address': {'uid': '12136',
#       'city': 'Qalqilya',
#       'stateOrProvince': 'West Bank',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4716',
#       'dateOfBirth': '1970',
#       'mainEntry': 'true'}}},
#    {'uid': '9654',
#     'firstName': 'Omar Mahmoud',
#     'lastName': 'MATAR',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'addressList': {'address': {'uid': '12137',
#       'city': 'Salfit',
#       'stateOrProvince': 'West Bank',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4717',
#       'dateOfBirth': '1958',
#       'mainEntry': 'true'}}},
#    {'uid': '9655',
#     'firstName': 'Muna Salim Saleh',
#     'lastName': 'MANSOUR',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9165',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'MANSOUR',
#       'firstName': 'Muna Salem'}},
#     'addressList': {'address': {'uid': '12138',
#       'city': 'Nablus',
#       'stateOrProvince': 'West Bank',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4718',
#       'dateOfBirth': '1961',
#       'mainEntry': 'true'}}},
#    {'uid': '9656',
#     'firstName': 'Yahia Abdul Aziz',
#     'lastName': 'AL-ABADSAH',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9166',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'EL ABADSA',
#       'firstName': 'Yehia Abdul Aziz'}},
#     'addressList': {'address': {'uid': '12139',
#       'city': 'Khan Younis',
#       'stateOrProvince': 'West Bank',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4719',
#       'dateOfBirth': '1958',
#       'mainEntry': 'true'}}},
#    {'uid': '9657',
#     'firstName': 'Mohammed Maher Yousef',
#     'lastName': 'BADER',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'addressList': {'address': {'uid': '12140',
#       'city': 'Hebron',
#       'stateOrProvince': 'West Bank',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4720',
#       'dateOfBirth': '1956',
#       'mainEntry': 'true'}}},
#    {'uid': '9658',
#     'firstName': 'Ayman Hussein',
#     'lastName': 'DARAGHMEH',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'addressList': {'address': {'uid': '12141',
#       'city': 'Tubas',
#       'stateOrProvince': 'West Bank',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4721',
#       'dateOfBirth': '1963',
#       'mainEntry': 'true'}}},
#    {'uid': '9659',
#     'firstName': 'Fathi Ahmad Mohammad',
#     'lastName': 'HAMMAD',
#     'sdnType': 'Individual',
#     'programList': {'program': ['NS-PLC', 'SDGT']},
#     'akaList': {'aka': [{'uid': '32437',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'HAMMAD',
#        'firstName': 'Fathi Ahmad'},
#       {'uid': '32438',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'HAMAD',
#        'firstName': 'Fathy Ahmed'},
#       {'uid': '32439',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'HAMAD',
#        'firstName': 'Fathi'}]},
#     'addressList': {'address': {'uid': '31130',
#       'city': 'Jabaliya',
#       'country': 'Region: Gaza'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4722',
#       'dateOfBirth': '1961',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '21061',
#       'placeOfBirth': 'Jabaliya, Gaza Strip',
#       'mainEntry': 'true'}}},
#    {'uid': '9660',
#     'firstName': 'Mariam Mohammed',
#     'lastName': 'FARHAT',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'addressList': {'address': {'uid': '12142',
#       'stateOrProvince': 'Gaza',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4723',
#       'dateOfBirth': '1949',
#       'mainEntry': 'true'}}},
#    {'uid': '9661',
#     'firstName': 'Sayyed Salem',
#     'lastName': 'ABU MSAMEH',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9167',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'ABU MUSAMEH',
#       'firstName': 'Sayed Salem'}},
#     'addressList': {'address': {'uid': '12143',
#       'city': 'Rafah',
#       'stateOrProvince': 'West Bank',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4724',
#       'dateOfBirth': '1948',
#       'mainEntry': 'true'}}},
#    {'uid': '9662',
#     'firstName': 'Marwan Mohammed',
#     'lastName': 'ABU RAS',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9168',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'ABOU RAAS',
#       'firstName': 'Merwan Muhammed'}},
#     'addressList': {'address': {'uid': '12144',
#       'city': 'Gaza City',
#       'stateOrProvince': 'Gaza',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4725',
#       'dateOfBirth': '1958',
#       'mainEntry': 'true'}}},
#    {'uid': '9663',
#     'firstName': 'Samira Abdullah',
#     'lastName': 'HALAYQAH',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9169',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'HALAYQA',
#       'firstName': 'Sameera Abed Allah'}},
#     'addressList': {'address': {'uid': '12145',
#       'city': 'Hebron',
#       'stateOrProvince': 'West Bank',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4726',
#       'dateOfBirth': '1964',
#       'mainEntry': 'true'}}},
#    {'uid': '9664',
#     'firstName': 'Jamal Ismail',
#     'lastName': 'ISKEIK',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'addressList': {'address': {'uid': '12146',
#       'stateOrProvince': 'Gaza',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4727',
#       'dateOfBirth': '1964',
#       'mainEntry': 'true'}}},
#    {'uid': '9665',
#     'firstName': 'Ali Salim',
#     'lastName': 'ROUMANIN',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'addressList': {'address': {'uid': '12147',
#       'city': 'Oja',
#       'stateOrProvince': 'West Bank',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4728',
#       'dateOfBirth': '1971',
#       'mainEntry': 'true'}}},
#    {'uid': '9666',
#     'firstName': 'Ahmad Yousef',
#     'lastName': 'ABU HALABIYYE',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'addressList': {'address': {'uid': '12148',
#       'city': 'Gaza City',
#       'stateOrProvince': 'Gaza',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4729',
#       'dateOfBirth': '1952',
#       'mainEntry': 'true'}}},
#    {'uid': '9667',
#     'firstName': 'Abdul Jaber Mustafa',
#     'lastName': 'FUQAHA',
#     'sdnType': 'Individual',
#     'programList': {'program': 'NS-PLC'},
#     'addressList': {'address': {'uid': '12149',
#       'city': 'Ramallah',
#       'stateOrProvince': 'West Bank',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4730',
#       'dateOfBirth': '1966',
#       'mainEntry': 'true'}}},
#    {'uid': '9668',
#     'firstName': 'Aziz',
#     'lastName': 'DWEIK',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Hebron',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9170',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'DWAIK',
#       'firstName': 'Aziz Salem Mustada'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4731',
#       'dateOfBirth': '1948',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '4732',
#       'placeOfBirth': 'Al-Khalil, Hebron',
#       'mainEntry': 'true'}}},
#    {'uid': '9669',
#     'firstName': 'Azzam',
#     'lastName': 'SALHAB',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Hebron',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': [{'uid': '9171',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'SALHAB',
#        'firstName': 'Azzam Numan Rahman'},
#       {'uid': '9172',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'SALHAB TAMIMI',
#        'firstName': "Azzam No'man Abdel Rahman"}]},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4733',
#       'dateOfBirth': '1956',
#       'mainEntry': 'true'}}},
#    {'uid': '9670',
#     'firstName': 'Nizar',
#     'lastName': 'RAMADAN',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Hebron',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9173',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'RAMADAN',
#       'firstName': 'Nizar Abd-Al-Aziz'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4734',
#       'dateOfBirth': '1960',
#       'mainEntry': 'true'}}},
#    {'uid': '9671',
#     'firstName': 'Nayef',
#     'lastName': 'RJOUB',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Hebron',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9174',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'RAJOUB',
#       'firstName': 'Naif Mahmod'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4735',
#       'dateOfBirth': '1958',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '4736',
#       'placeOfBirth': 'Dura, West Bank',
#       'mainEntry': 'true'}}},
#    {'uid': '9672',
#     'firstName': 'Samir',
#     'lastName': 'AL-QADI',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Hebron',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9175',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'AL-QADI',
#       'firstName': 'Sameer Saleh'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4737',
#       'dateOfBirth': '1956',
#       'mainEntry': 'true'}}},
#    {'uid': '9673',
#     'firstName': 'Mohammed',
#     'lastName': 'ABU JHEISHEH',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Hebron',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': [{'uid': '9176',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'ABU JHESHEH',
#        'firstName': 'Mohammad Mutlaq'},
#       {'uid': '9177',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'ABU JEHEISHA',
#        'firstName': 'Mohammed'}]},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4738',
#       'dateOfBirth': '1955',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '4739',
#       'placeOfBirth': 'Izna, Hebron',
#       'mainEntry': 'true'}}},
#    {'uid': '9674',
#     'firstName': 'Hatem',
#     'lastName': 'QFEISHEH',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Hebron',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': [{'uid': '9178',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'KAFEESHEH',
#        'firstName': 'Hatem Rabah'},
#       {'uid': '9179',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'QEFEISHA',
#        'firstName': 'Hatem'},
#       {'uid': '9180',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'ABU ANED',
#        'firstName': 'Hadj Hatem'}]},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4740',
#       'dateOfBirth': '1960',
#       'mainEntry': 'true'}}},
#    {'uid': '9675',
#     'firstName': 'Basem',
#     'lastName': "ZA'ARIR",
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Hebron',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9181',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'ZAAREER',
#       'firstName': 'Basim Ahmad'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4741',
#       'dateOfBirth': '1962',
#       'mainEntry': 'true'}}},
#    {'uid': '9676',
#     'firstName': 'Mohammed',
#     'lastName': 'AL-TAL',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Hebron',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9182',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'AL-TAL',
#       'firstName': 'Mohammad Ismail'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4742',
#       'dateOfBirth': '1965',
#       'mainEntry': 'true'}}},
#    {'uid': '9677',
#     'firstName': 'Daoud',
#     'lastName': 'ABU SEIR',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Hebron',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9183',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'ABU SAIR',
#       'firstName': "Da'oud Kamal Da'oud"}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4743',
#       'dateOfBirth': '1955',
#       'mainEntry': 'true'}}},
#    {'uid': '9678',
#     'firstName': 'Hamid Jabir',
#     'lastName': 'KHUDAIR',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Nablus',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9184',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'KHUDAIR',
#       'firstName': 'Hamid Sulieman Jabir'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4744',
#       'dateOfBirth': '1944',
#       'mainEntry': 'true'}}},
#    {'uid': '9679',
#     'firstName': 'Husni Bourini',
#     'lastName': 'YASIN',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Nablus',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9185',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'YASIN',
#       'firstName': 'Husni Mohammad Bourini'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4745',
#       'dateOfBirth': '1955',
#       'mainEntry': 'true'}}},
#    {'uid': '9680',
#     'firstName': 'Riyad Ali',
#     'lastName': 'AMLI',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Nablus',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9186',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'AMLI',
#       'firstName': 'Riyad Ali Mustafa'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4746',
#       'dateOfBirth': '1961',
#       'mainEntry': 'true'}}},
#    {'uid': '9681',
#     'firstName': 'Ahmad Ali',
#     'lastName': 'AHMAD',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Nablus',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9187',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'AHMAD',
#       'firstName': 'Ahmad Ali Ahmad'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4747',
#       'dateOfBirth': '1940',
#       'mainEntry': 'true'}}},
#    {'uid': '9682',
#     'firstName': 'Hasan',
#     'lastName': 'YOUSEF',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Ramallah',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': [{'uid': '9188',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'DAR KHALIL',
#        'firstName': 'Hasan Youssef Daoud'},
#       {'uid': '9189',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'DAR KHALIL',
#        'firstName': 'Hassan Yousef Dawoud'}]}},
#    {'uid': '9683',
#     'firstName': 'Fadel',
#     'lastName': 'HAMDAN',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Ramallah',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9190',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'HAMDAN',
#       'firstName': 'Fadel Mohammad Saleh'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4748',
#       'dateOfBirth': '1953',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '4749',
#       'placeOfBirth': 'Ramallah, West Bank',
#       'mainEntry': 'true'}}},
#    {'uid': '9684',
#     'firstName': 'Mahmoud',
#     'lastName': 'MUSLEH',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Ramallah',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9191',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'MUSLEH',
#       'firstName': 'Mahmoud Ibrahim Mahmoud'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4750',
#       'dateOfBirth': '1941',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '4751',
#       'placeOfBirth': 'Haifa, Israel',
#       'mainEntry': 'true'}}},
#    {'uid': '9685',
#     'firstName': "Ahmad 'Abd al-Aziz",
#     'lastName': 'MUBARAK',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Ramallah',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9192',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'MUBARAK',
#       'firstName': 'Ahmad Abdel Aziz Saleh'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4752',
#       'dateOfBirth': '1962',
#       'mainEntry': 'true'}}},
#    {'uid': '9686',
#     'firstName': 'Khaled Tafish',
#     'lastName': 'THWEIB',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Bethlehem',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': [{'uid': '9193',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'THOUAIB',
#        'firstName': 'Khaled Ibrahim Tafish'},
#       {'uid': '9194',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'DWEIB',
#        'firstName': 'Khaled Tafesh'}]},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4753',
#       'dateOfBirth': '1964',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '4754',
#       'placeOfBirth': 'Bethlehem',
#       'mainEntry': 'true'}}},
#    {'uid': '9687',
#     'firstName': 'Mahmoud',
#     'lastName': 'AL-KHATIB',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Bethlehem',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9195',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'AL-KHATIB',
#       'firstName': 'Mahmoud Daoud Mahmoud'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4755',
#       'dateOfBirth': '1972',
#       'mainEntry': 'true'}}},
#    {'uid': '9688',
#     'firstName': 'Khaled Abed',
#     'lastName': 'YAHIA',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Jenin',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9196',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'YEHIA',
#       'firstName': 'Khaled Said'}},
#     'addressList': {'address': {'uid': '12150',
#       'city': 'Jenin',
#       'stateOrProvince': 'West Bank',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4756',
#       'dateOfBirth': '1959',
#       'mainEntry': 'true'}}},
#    {'uid': '9689',
#     'firstName': 'Khaled',
#     'lastName': 'ABU HASSAN',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Jenin',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': [{'uid': '9197',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'ABOU HASSAN',
#        'firstName': 'Khaled Suleiman Fayez'},
#       {'uid': '9198',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'ABU HASAN',
#        'firstName': 'Khalid Sulayman Fayiz'}]},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4757',
#       'dateOfBirth': '1967',
#       'mainEntry': 'true'}}},
#    {'uid': '9690',
#     'firstName': 'Abdul Rahman Fahmi',
#     'lastName': 'ZEIDAN',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Tulkarem',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9199',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'ZEIDAN',
#       'firstName': 'Abdel Rahman Fahmi Rahman'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4758',
#       'dateOfBirth': '1960',
#       'mainEntry': 'true'}}},
#    {'uid': '9691',
#     'firstName': 'Riyad',
#     'lastName': 'RADDAD',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Tulkarem',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': [{'uid': '9200',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'RADAD',
#        'firstName': "Riyad Mahmoud Sa'eed"},
#       {'uid': '9201',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'AL-SEDAWI',
#        'firstName': 'Riyad Radad'}]},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4759',
#       'dateOfBirth': '1960',
#       'mainEntry': 'true'}}},
#    {'uid': '9692',
#     'firstName': 'Ahmad',
#     'lastName': 'ATTOUN',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Jerusalem',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': [{'uid': '9202',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'ATTOUN',
#        'firstName': 'Ahmad Mohammad Ahmad'},
#       {'uid': '9203',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'ATOON',
#        'firstName': 'Ahmed Muhamad Ahmed'}]},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4760',
#       'dateOfBirth': '1968',
#       'mainEntry': 'true'}}},
#    {'uid': '9693',
#     'firstName': 'Ibrahim',
#     'lastName': 'ABU SALEM',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Jerusalem',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9204',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'ABOU SALEM',
#       'firstName': 'Ibrahim Said Hasan'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4761',
#       'dateOfBirth': '1948',
#       'mainEntry': 'true'}}},
#    {'uid': '9694',
#     'firstName': 'Mohammed Saleh',
#     'lastName': 'TUTAH',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Jerusalem',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': [{'uid': '9205',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'TAWTAH',
#        'firstName': 'Mohammad Omran Saleh'},
#       {'uid': '9206',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'TAWTA',
#        'firstName': 'Muhamed Umran Salih'}]},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4762',
#       'dateOfBirth': '1969',
#       'mainEntry': 'true'}}},
#    {'uid': '9695',
#     'firstName': 'Wael',
#     'lastName': 'AL-HUSSEINI',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Jerusalem',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': [{'uid': '9207',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'ABDUL RAHMAN',
#        'firstName': 'Wael Muhammed'},
#       {'uid': '9208',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'ABED AL RAHMAAN',
#        'firstName': 'Wael Mohamad'}]},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4763',
#       'dateOfBirth': '1962',
#       'mainEntry': 'true'}}},
#    {'uid': '9696',
#     'firstName': 'Naser',
#     'lastName': 'ABDUL JAWAD',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Salfit',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9209',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'ABDEL JAWAD',
#       'firstName': 'Nasir Abdullah Odeh'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4764',
#       'dateOfBirth': '1965',
#       'mainEntry': 'true'}}},
#    {'uid': '9697',
#     'firstName': 'Khaled',
#     'lastName': 'ABU TOS',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Toubas',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9210',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'ABU QOUS',
#       'firstName': 'Khalid Hamad Hamid'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4765',
#       'dateOfBirth': '1949',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '4766',
#       'placeOfBirth': 'Tulkarem, West Bank',
#       'mainEntry': 'true'}}},
#    {'uid': '9698',
#     'firstName': 'Khamis',
#     'lastName': 'NAJJAR',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Khan Younis',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9211',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'NAJJAR',
#       'firstName': 'Khamis Jawdat Khamis'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4767',
#       'dateOfBirth': '1949',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '4768',
#       'placeOfBirth': 'Khan Younis',
#       'mainEntry': 'true'}}},
#    {'uid': '9699',
#     'firstName': 'Salah',
#     'lastName': 'AL-BARDAWIL',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Khan Younis',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9212',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'EL BARDAWIL',
#       'firstName': 'Salah Mohammad'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4769',
#       'dateOfBirth': '1959',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '4770',
#       'placeOfBirth': 'Khan Younis',
#       'mainEntry': 'true'}}},
#    {'uid': '9700',
#     'firstName': 'Younes',
#     'lastName': 'AL-ASTAL',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Khan Younis',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9213',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'EL-ASTAL',
#       'firstName': 'Younis Mohe-eldeen Fayez'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4771',
#       'dateOfBirth': '1956',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '4772',
#       'placeOfBirth': 'Khan Younis',
#       'mainEntry': 'true'}}},
#    {'uid': '9701',
#     'firstName': 'Abdul Rahman',
#     'lastName': 'AL-JAMAL',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Der al-Balah',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9214',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'AL-JAMAL',
#       'firstName': 'Abdel Al-Rahman Yusef'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4773',
#       'dateOfBirth': '1961',
#       'mainEntry': 'true'}}},
#    {'uid': '9702',
#     'firstName': 'Salem',
#     'lastName': 'SALAMEH',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Der al-Balah',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9215',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'SALAMEH',
#       'firstName': 'Salem Ahmad Abdel Hadi'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4774',
#       'dateOfBirth': '1951',
#       'mainEntry': 'true'}}},
#    {'uid': '9703',
#     'firstName': 'Saeed',
#     'lastName': 'SIAM',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Gaza',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': [{'uid': '9216',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'SEYAM',
#        'firstName': 'Said Mohammad'},
#       {'uid': '9217',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'SIYAM',
#        'firstName': 'Saeed Mohammad'}]},
#     'addressList': {'address': {'uid': '12151',
#       'stateOrProvince': 'Gaza',
#       'country': 'Palestinian'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4775',
#       'dateOfBirth': '1959',
#       'mainEntry': 'true'}}},
#    {'uid': '9704',
#     'firstName': 'Ahmad',
#     'lastName': 'BAHAR',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Gaza',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9218',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'BAHAR',
#       'firstName': 'Ahmed Mohamed'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4776',
#       'dateOfBirth': '1949',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '4777',
#       'placeOfBirth': 'Gaza',
#       'mainEntry': 'true'}}},
#    {'uid': '9705',
#     'firstName': 'Jamal',
#     'lastName': 'SALEH',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Gaza',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': [{'uid': '9219',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'NASSER',
#        'firstName': 'Jamal Talab Mohammad Saleh'},
#       {'uid': '9220',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'SALEH',
#        'firstName': 'Jamal Talab'}]},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4778',
#       'dateOfBirth': '1958',
#       'mainEntry': 'true'}},
#     'placeOfBirthList': {'placeOfBirthItem': {'uid': '4779',
#       'placeOfBirth': 'Gaza',
#       'mainEntry': 'true'}}},
#    {'uid': '9706',
#     'firstName': 'Khalil',
#     'lastName': 'AL-HAYYEH',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Gaza',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9221',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'ELHYYA',
#       'firstName': 'Khalil Esmaeel'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4780',
#       'dateOfBirth': '1960',
#       'mainEntry': 'true'}}},
#    {'uid': '9707',
#     'firstName': 'Mohammed Faraj',
#     'lastName': 'AL-GHOUL',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Gaza',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9222',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'ELGHOUL',
#       'firstName': 'Mohammad Faraj Mahmood'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4781',
#       'dateOfBirth': '1957',
#       'mainEntry': 'true'}}},
#    {'uid': '9708',
#     'firstName': 'Mushir',
#     'lastName': 'AL-HABAL',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Northern Gaza',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': [{'uid': '9223',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'ELHABEL',
#        'firstName': 'Moshir Omar'},
#       {'uid': '9224',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'EL-MASRI',
#        'firstName': 'Moshir'}]},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4782',
#       'dateOfBirth': '1978',
#       'mainEntry': 'true'}}},
#    {'uid': '9709',
#     'firstName': 'Atef',
#     'lastName': 'UDWAN',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Northern Gaza',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': [{'uid': '9225',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'ADWAN',
#        'firstName': 'Atef Ibrahim'},
#       {'uid': '9226',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'IDWAN',
#        'firstName': 'Atef Ibrahim Mohammad'}]},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4783',
#       'dateOfBirth': '1952',
#       'mainEntry': 'true'}}},
#    {'uid': '9710',
#     'firstName': 'Yousef',
#     'lastName': 'AL-SHARAFI',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Northern Gaza',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9227',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'AL-SHRAFI',
#       'firstName': 'Yousef Awad'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4784',
#       'dateOfBirth': '1963',
#       'mainEntry': 'true'}}},
#    {'uid': '9711',
#     'firstName': 'Ismail',
#     'lastName': 'AL-ASHQAR',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Northern Gaza',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9228',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'AL-ALASHQAR',
#       'firstName': 'Ismail Abdallatif'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4785',
#       'dateOfBirth': '1962',
#       'mainEntry': 'true'}}},
#    {'uid': '9712',
#     'firstName': 'Mohammed',
#     'lastName': 'SHIHAB',
#     'sdnType': 'Individual',
#     'remarks': 'HAMAS - Northern Gaza',
#     'programList': {'program': 'NS-PLC'},
#     'akaList': {'aka': {'uid': '9229',
#       'type': 'a.k.a.',
#       'category': 'strong',
#       'lastName': 'SHEHAB',
#       'firstName': 'Mohamed Abed Hadi Rahman'}},
#     'dateOfBirthList': {'dateOfBirthItem': {'uid': '4786',
#       'dateOfBirth': '1956',
#       'mainEntry': 'true'}}},
#    {'uid': '9713',
#     'firstName': 'Ahmad',
#     'lastName': "SA'DAT",
#     'sdnType': 'Individual',
#     'remarks': 'PFLP',
#     'programList': {'program': 'NS-PLC'}},
#    {'uid': '9714',
#     'firstName': 'Jamil',
#     'lastName': 'MAJDALAWI',
#     'sdnType': 'Individual',
#     'remarks': 'PFLP',
#     'programList': {'program': 'NS-PLC'}},
#    {'uid': '9715',
#     'firstName': 'Khaledah',
#     'lastName': 'JARRAR',
#     'sdnType': 'Individual',
#     'remarks': 'PFLP',
#     'programList': {'program': 'NS-PLC'}},
#    {'uid': '9716',
#     'firstName': 'Qais Abdul',
#     'lastName': 'KARIM',
#     'sdnType': 'Individual',
#     'remarks': 'DFLP',
#     'programList': {'program': 'NS-PLC'}},
#    {'uid': '15268',
#     'lastName': 'BANK OF KUNLUN CO LTD',
#     'sdnType': 'Entity',
#     'remarks': 'United States financial institutions are prohibited from opening or maintaining a correspondent account or a payable-through account for the foreign financial institution listed here, pursuant to 31 C.F.R. section 561.201(c)',
#     'programList': {'program': '561-Related'},
#     'idList': {'id': {'uid': '111843',
#       'idType': 'SWIFT/BIC',
#       'idNumber': 'CKLBCNBJ'}},
#     'akaList': {'aka': [{'uid': '22509',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'KARAMAY URBAN CREDIT COOPERATIVES'},
#       {'uid': '22510',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'KARAMAY CITY COMMERCIAL BANK CO LTD.'}]},
#     'addressList': {'address': [{'uid': '22761',
#        'address1': '172 Xibin Rd',
#        'address2': 'Ranghulu District',
#        'address3': '(Daqing, Heilongjiang Branch)',
#        'city': 'Daqing',
#        'postalCode': '163453',
#        'country': 'China'},
#       {'uid': '22762',
#        'address1': '9 Dongzhimen North Street',
#        'address2': 'Dongcheng District',
#        'address3': '(Head Office)',
#        'city': 'Beijing',
#        'postalCode': '100007',
#        'country': 'China'},
#       {'uid': '22763',
#        'address1': 'No. 7 Century Ave',
#        'address3': '(Registered Office)',
#        'city': 'Xinjiang',
#        'stateOrProvince': 'Karamay',
#        'postalCode': '834000',
#        'country': 'China'},
#       {'uid': '22764',
#        'address1': 'No. 68 Zhongya South Rd',
#        'address2': 'Economic and Technological Development Zone',
#        'address3': '(Urumqi, Xinjiang Branch)',
#        'city': 'Urumqi',
#        'postalCode': '830026',
#        'country': 'China'}]}},
#    {'uid': '17013',
#     'lastName': 'VTB BANK PUBLIC JOINT STOCK COMPANY',
#     'sdnType': 'Entity',
#     'remarks': 'For more information on directives, please visit the following link: http://www.treasury.gov/resource-center/sanctions/Programs/Pages/ukraine.aspx#directives.',
#     'programList': {'program': ['UKRAINE-EO13662', 'RUSSIA-EO14024']},
#     'idList': {'id': [{'uid': '9477',
#        'idType': 'Registration ID',
#        'idNumber': '1027739609391',
#        'idCountry': 'Russia'},
#       {'uid': '9478',
#        'idType': 'Government Gazette Number',
#        'idNumber': '00032520',
#        'idCountry': 'Russia'},
#       {'uid': '9483',
#        'idType': 'Tax ID No.',
#        'idNumber': '7702070139',
#        'idCountry': 'Russia'},
#       {'uid': '9486',
#        'idType': 'License',
#        'idNumber': '1000',
#        'idCountry': 'Russia'},
#       {'uid': '24641',
#        'idType': 'Legal Entity Number',
#        'idNumber': '253400V1H6ART1UQ0N98',
#        'idCountry': 'Russia'},
#       {'uid': '115744', 'idType': 'SWIFT/BIC', 'idNumber': 'VTBRRUMM'},
#       {'uid': '115745', 'idType': 'Website', 'idNumber': 'www.vtb.com'},
#       {'uid': '116142',
#        'idType': 'Executive Order 13662 Directive Determination -',
#        'idNumber': 'Subject to Directive 1'},
#       {'uid': '146547', 'idType': 'Website', 'idNumber': 'www.vtb.ru'},
#       {'uid': '146548', 'idType': 'BIK (RU)', 'idNumber': '044030707'},
#       {'uid': '146549', 'idType': 'BIK (RU)', 'idNumber': '044525187'},
#       {'uid': '146553',
#        'idType': 'Organization Established Date',
#        'idNumber': '17 Oct 1990'},
#       {'uid': '146669',
#        'idType': 'Target Type',
#        'idNumber': 'Financial Institution'},
#       {'uid': '151145',
#        'idType': 'Secondary sanctions risk:',
#        'idNumber': 'Ukraine-/Russia-Related Sanctions Regulations, 31 CFR 589.201 and/or 589.209'}]},
#     'akaList': {'aka': [{'uid': '26072',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'JSC VTB BANK'},
#       {'uid': '26073',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'BANK VTB OPEN JOINT STOCK COMPANY'},
#       {'uid': '26075',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'BANK VNESHNEY TORGOVLI OPEN JOINT STOCK COMPANY'},
#       {'uid': '26076',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'BANK VNESHNEY TORGOVLI JOINT STOCK COMPANY'},
#       {'uid': '26077',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'BANK VNESHNEI TORGOVLI RSFSR'},
#       {'uid': '26078',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'BANK VNESHNEY TORGOVLI ROSSIYSKOY FEDERATSII CLOSED JOINT STOCK COMPANY'},
#       {'uid': '26079',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'VNESHTORGBANK ROSSII CLOSED JOINT STOCK COMPANY'},
#       {'uid': '26081',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'BANK VTB OAO'},
#       {'uid': '54895',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'VTB BANK PAO'},
#       {'uid': '54896',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'VTB BANK OAO'},
#       {'uid': '54900',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'VTB BANK PJSC'},
#       {'uid': '54902',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'BANK VTB PUBLICHNOE AKTSIONERNOE OBSHCHESTVO'},
#       {'uid': '54903',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'VTB BANK'},
#       {'uid': '54907',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'OAO BANK VTB'},
#       {'uid': '54908',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'VTB BANK OPEN JOINT STOCK COMPANY'},
#       {'uid': '54909',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'BANK VNESHEI TORGOVLI OAO'},
#       {'uid': '54912',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'BANK VNESHNEI TORGOVLI ROSSISKOI FEDERATSII AS A PRIVATE JOINT STOCK COMPANY'},
#       {'uid': '54914',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'OAO VNESHTORGBANK'},
#       {'uid': '54940',
#        'type': 'f.k.a.',
#        'category': 'strong',
# ...
#       'address2': '12 Science Park',
#       'address3': 'West Avenue',
#       'city': 'Hong Kong New Territories',
#       'stateOrProvince': 'Hong Kong SAR',
#       'country': 'China'}}},
#    {'uid': '33893',
#     'lastName': 'YITU LIMITED',
#     'sdnType': 'Entity',
#     'programList': {'program': 'CMIC-EO13959'},
#     'idList': {'id': [{'uid': '145551',
#        'idType': 'Effective Date (CMIC)',
#        'idNumber': '14 Feb 2022'},
#       {'uid': '145552',
#        'idType': 'Purchase/Sales For Divestment Date (CMIC)',
#        'idNumber': '16 Dec 2022'},
#       {'uid': '145554',
#        'idType': 'Listing Date (CMIC)',
#        'idNumber': '16 Dec 2021'}]},
#     'addressList': {'address': {'uid': '50764',
#       'address1': 'Suite #4-210',
#       'address2': 'Governors Square',
#       'address3': '23 Lime Tree Bay Avenue, PO Box 23211',
#       'city': 'Grand Cayman',
#       'postalCode': 'KY1-1209',
#       'country': 'Cayman Islands'}}},
#    {'uid': '33894',
#     'lastName': 'LEON TECHNOLOGY COMPANY LIMITED',
#     'sdnType': 'Entity',
#     'programList': {'program': 'CMIC-EO13959'},
#     'idList': {'id': [{'uid': '23531',
#        'idType': 'Unified Social Credit Code (USCC)',
#        'idNumber': '916501002999341738',
#        'idCountry': 'China'},
#       {'uid': '144827', 'idType': 'ISIN', 'idNumber': 'CNE100002Q17'},
#       {'uid': '144828', 'idType': 'Equity Ticker', 'idNumber': '300603 CN'},
#       {'uid': '144829',
#        'idType': 'Issuer Name',
#        'idNumber': 'Leon Technology Co., Ltd.'},
#       {'uid': '145556',
#        'idType': 'Effective Date (CMIC)',
#        'idNumber': '14 Feb 2022'},
#       {'uid': '145557',
#        'idType': 'Purchase/Sales For Divestment Date (CMIC)',
#        'idNumber': '16 Dec 2022'},
#       {'uid': '145558',
#        'idType': 'Listing Date (CMIC)',
#        'idNumber': '16 Dec 2021'}]},
#     'akaList': {'aka': [{'uid': '53113',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'LEON TECHNOLOGY CO., LTD.'},
#       {'uid': '53114',
#        'type': 'a.k.a.',
#        'category': 'weak',
#        'lastName': 'LEON TECHNOLOGY'}]},
#     'addressList': {'address': {'uid': '50766',
#       'address1': 'High-Tech Zone',
#       'address2': 'Century Pacific International Centre, 416',
#       'address3': 'South Beijing Road',
#       'city': 'Urumqi',
#       'postalCode': '830000',
#       'country': 'China'}}},
#    {'uid': '33895',
#     'lastName': 'NETPOSA TECHNOLOGIES LIMITED',
#     'sdnType': 'Entity',
#     'programList': {'program': 'CMIC-EO13959'},
#     'idList': {'id': [{'uid': '23532',
#        'idType': 'Unified Social Credit Code (USCC)',
#        'idNumber': '91110000721497432T',
#        'idCountry': 'China'},
#       {'uid': '144830',
#        'idType': 'Issuer Name',
#        'idNumber': 'NetPosa Technologies, Ltd.'},
#       {'uid': '144831', 'idType': 'ISIN', 'idNumber': 'CNE100001S40'},
#       {'uid': '144832', 'idType': 'Equity Ticker', 'idNumber': '300367 CN'},
#       {'uid': '145559',
#        'idType': 'Effective Date (CMIC)',
#        'idNumber': '14 Feb 2022'},
#       {'uid': '145560',
#        'idType': 'Listing Date (CMIC)',
#        'idNumber': '16 Dec 2021'},
#       {'uid': '145561',
#        'idType': 'Purchase/Sales For Divestment Date (CMIC)',
#        'idNumber': '16 Dec 2022'}]},
#     'akaList': {'aka': [{'uid': '53116',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'NETPOSA TECHNOLOGIES, LTD.'},
#       {'uid': '53117',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'NETPOSA'}]},
#     'addressList': {'address': {'uid': '50768',
#       'address1': 'Wangjing Soho, 2nd Tower, 26th Floor',
#       'address2': '1, Futong Avenue',
#       'address3': 'Chaoyang District',
#       'city': 'Beijing',
#       'postalCode': '100102',
#       'country': 'China'}}},
#    {'uid': '33896',
#     'lastName': 'XIAMEN MEIYA PICO INFORMATION CO., LTD.',
#     'sdnType': 'Entity',
#     'programList': {'program': 'CMIC-EO13959'},
#     'idList': {'id': [{'uid': '23533',
#        'idType': 'Unified Social Credit Code (USCC)',
#        'idNumber': '91350200705420347R',
#        'idCountry': 'China'},
#       {'uid': '144833',
#        'idType': 'Issuer Name',
#        'idNumber': 'Xiamen Meiya Pico Information Co., Ltd.'},
#       {'uid': '144834', 'idType': 'Equity Ticker', 'idNumber': '300188 CN'},
#       {'uid': '144835', 'idType': 'ISIN', 'idNumber': 'CNE100001120'},
#       {'uid': '145562',
#        'idType': 'Effective Date (CMIC)',
#        'idNumber': '14 Feb 2022'},
#       {'uid': '145563',
#        'idType': 'Listing Date (CMIC)',
#        'idNumber': '16 Dec 2021'},
#       {'uid': '145564',
#        'idType': 'Purchase/Sales For Divestment Date (CMIC)',
#        'idNumber': '16 Dec 2022'}]},
#     'addressList': {'address': {'uid': '50771',
#       'address1': '2nd Phase of Xiamen Software Park',
#       'address2': 'Meiya Pico Building',
#       'address3': '12 Guanri Road',
#       'city': 'Xiamen',
#       'postalCode': '361008',
#       'country': 'China'}}},
#    {'uid': '34556',
#     'lastName': 'PUBLIC JOINT STOCK COMPANY ROSTELECOM',
#     'sdnType': 'Entity',
#     'programList': {'program': 'RUSSIA-EO14024'},
#     'idList': {'id': [{'uid': '24196',
#        'idType': 'Registration Number',
#        'idNumber': '1027700198767',
#        'idCountry': 'Russia'},
#       {'uid': '24197',
#        'idType': 'Tax ID No.',
#        'idNumber': '7707049388',
#        'idCountry': 'Russia'},
#       {'uid': '24198',
#        'idType': 'Legal Entity Number',
#        'idNumber': '2534001D752JPNM0H170',
#        'idCountry': 'Russia'},
#       {'uid': '145990',
#        'idType': 'Organization Established Date',
#        'idNumber': '1993'},
#       {'uid': '146675',
#        'idType': 'Executive Order 14024 Directive Information',
#        'idNumber': "Subject to Directive 3 - All transactions in, provision of financing for, and other dealings in new debt of longer than 14 days maturity or new equity where such new debt or new equity is issued on or after the 'Effective Date (EO 14024 Directive)' associated with this name are prohibited."},
#       {'uid': '146676',
#        'idType': 'Executive Order 14024 Directive Information -',
#        'idNumber': 'For more information on directives, please visit the following link: https://home.treasury.gov/policy-issues/financial-sanctions/sanctions-programs-and-country-information/russian-harmful-foreign-activities-sanctions#directives'},
#       {'uid': '146819',
#        'idType': 'Listing Date (EO 14024 Directive 3):',
#        'idNumber': '24 Feb 2022'},
#       {'uid': '146820',
#        'idType': 'Effective Date (EO 14024 Directive 3):',
#        'idNumber': '26 Mar 2022'}]},
#     'akaList': {'aka': [{'uid': '54107',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'ROSTELEKOM PJSC'},
#       {'uid': '54108',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'PJSC ROSTELECOM'},
#       {'uid': '54109',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'PUBLICHNOE AKTSIONERNOY OBSHCHESTVO ROSTELEKOM'},
#       {'uid': '54110',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'PUBLICHNOE AKTSIONERNOE OBSHCHESTVO ROSTELEKOM'},
#       {'uid': '54111',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'ROSTELECOM'},
#       {'uid': '54112',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'PAO MEZHDUGORODNOI I MEZHDUNARODNOI ELEKTRICHESKOI SVYAZI ROSTELEKOM'}]},
#     'addressList': {'address': [{'uid': '51785',
#        'address1': 'P.O. Box: 14, 1, Tverskaya-Yamskaya Street',
#        'city': 'Moscow',
#        'postalCode': '125047',
#        'country': 'Russia'},
#       {'uid': '51787',
#        'address1': '30 (building 1), Goncharnaya st.',
#        'city': 'Moscow',
#        'postalCode': '115172',
#        'country': 'Russia'},
#       {'uid': '51788',
#        'address1': 'd. 14 litera A, naberezhnaya Sinopskaya',
#        'city': 'St. Petersburg',
#        'postalCode': '191167',
#        'country': 'Russia'}]}},
#    {'uid': '34578',
#     'lastName': 'PUBLIC JOINT STOCK COMPANY RUSHYDRO',
#     'sdnType': 'Entity',
#     'programList': {'program': 'RUSSIA-EO14024'},
#     'idList': {'id': [{'uid': '24290',
#        'idType': 'Legal Entity Number',
#        'idNumber': '2534005TJN9DX4YWVT97',
#        'idCountry': 'Russia'},
#       {'uid': '24292',
#        'idType': 'Registration Number',
#        'idNumber': '1042401810494',
#        'idCountry': 'Russia'},
#       {'uid': '24293',
#        'idType': 'Tax ID No.',
#        'idNumber': '2460066195',
#        'idCountry': 'Russia'},
#       {'uid': '146057',
#        'idType': 'Organization Established Date',
#        'idNumber': '2004'},
#       {'uid': '146682',
#        'idType': 'Executive Order 14024 Directive Information',
#        'idNumber': "Subject to Directive 3 - All transactions in, provision of financing for, and other dealings in new debt of longer than 14 days maturity or new equity where such new debt or new equity is issued on or after the 'Effective Date (EO 14024 Directive)' associated with this name are prohibited."},
#       {'uid': '146710',
#        'idType': 'Executive Order 14024 Directive Information -',
#        'idNumber': 'For more information on directives, please visit the following link: https://home.treasury.gov/policy-issues/financial-sanctions/sanctions-programs-and-country-information/russian-harmful-foreign-activities-sanctions#directives'},
#       {'uid': '146823',
#        'idType': 'Listing Date (EO 14024 Directive 3):',
#        'idNumber': '24 Feb 2022'},
#       {'uid': '146824',
#        'idType': 'Effective Date (EO 14024 Directive 3):',
#        'idNumber': '26 Mar 2022'}]},
#     'akaList': {'aka': [{'uid': '54302',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'PUBLIC JOINT-STOCK COMPANY FEDERAL HYDRO-GENERATING COMPANY - RUSHYDRO'},
#       {'uid': '54303',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'FEDERAL HYDRO-GENERATING COMPANY RUSHYDRO PAO'},
#       {'uid': '54304',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'PUBLICHNOE AKTSIONERNOE OBSCHESTVO FEDERALNAYA GYDROGENERIRUYUSCHAYA KOMPANIYA-RUSGYDRO'},
#       {'uid': '54305',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'PUBLICHNOE AKTSIONERNOE OBSHCHESTVO FEDERALNAYA GIDROGENERIRUYUSHCHAYA KOMPANIYA - RUSGIDRO'},
#       {'uid': '54306',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'RUSGIDRO, PAO'},
#       {'uid': '54309',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'FEDERAL HYDRO-GENERATING COMPANY RUSHYDRO OAO'},
#       {'uid': '54310',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'GIDROOGK OAO'},
#       {'uid': '54312',
#        'type': 'f.k.a.',
#        'category': 'strong',
#        'lastName': 'OTKRYTOE AKTSIONERNOE OBSCHESTVO FEDERALNAYA GYDROGENERIRUYUSCHAYA KOMPANIYA-RUSGYDRO'}]},
#     'addressList': {'address': [{'uid': '51904',
#        'address1': '51, Republic Street',
#        'city': 'Kedrovyy',
#        'country': 'Russia'},
#       {'uid': '51907',
#        'address1': 'd. 43 k. 1, ul. Dubrovinskogo',
#        'city': 'Krasnoyarsk',
#        'stateOrProvince': 'Krasnoyarski Kr.',
#        'postalCode': '660017',
#        'country': 'Russia'},
#       {'uid': '51908',
#        'address1': '23 Pravda St',
#        'city': 'Moscow',
#        'postalCode': '127015',
#        'country': 'Russia'},
#       {'uid': '51909',
#        'address1': 'Mail Box No. 54',
#        'city': 'Moscow',
#        'postalCode': '127137',
#        'country': 'Russia'}]}},
#    {'uid': '34736',
#     'lastName': 'OPEN JOINT STOCK COMPANY RUSSIAN RAILWAYS',
#     'sdnType': 'Entity',
#     'programList': {'program': 'RUSSIA-EO14024'},
#     'idList': {'id': [{'uid': '24397',
#        'idType': 'Registration Number',
#        'idNumber': '1037739877295',
#        'idCountry': 'Russia'},
#       {'uid': '24398',
#        'idType': 'Tax ID No.',
#        'idNumber': '7708503727',
#        'idCountry': 'Russia'},
#       {'uid': '24399',
#        'idType': 'Legal Entity Number',
#        'idNumber': '253400XX5U3XALBF5728',
#        'idCountry': 'Russia'},
#       {'uid': '146167', 'idType': 'Website', 'idNumber': 'www.rzd.ru'},
#       {'uid': '146168',
#        'idType': 'Target Type',
#        'idNumber': 'Government Entity'},
#       {'uid': '146169',
#        'idType': 'Organization Established Date',
#        'idNumber': '18 Sep 2003'},
#       {'uid': '146686',
#        'idType': 'Executive Order 14024 Directive Information',
#        'idNumber': "Subject to Directive 3 - All transactions in, provision of financing for, and other dealings in new debt of longer than 14 days maturity or new equity where such new debt or new equity is issued on or after the 'Effective Date (EO 14024 Directive)' associated with this name are prohibited."},
#       {'uid': '146713',
#        'idType': 'Executive Order 14024 Directive Information -',
#        'idNumber': 'For more information on directives, please visit the following link: https://home.treasury.gov/policy-issues/financial-sanctions/sanctions-programs-and-country-information/russian-harmful-foreign-activities-sanctions#directives'},
#       {'uid': '146837',
#        'idType': 'Listing Date (EO 14024 Directive 3):',
#        'idNumber': '24 Feb 2022'},
#       {'uid': '146838',
#        'idType': 'Effective Date (EO 14024 Directive 3):',
#        'idNumber': '26 Mar 2022'}]},
#     'akaList': {'aka': [{'uid': '54467',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'JSC RUSSIAN RAILWAYS'},
#       {'uid': '54468',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'RUSSIAN RAILWAYS JSC'},
#       {'uid': '54469',
#        'type': 'a.k.a.',
#        'category': 'strong',
#        'lastName': 'RUSSIAN RAILWAYS'},
#       {'uid': '54470',
#        'type': 'a.k.a.',
#        'category': 'weak',
#        'lastName': 'JSC RZD'},
#       {'uid': '54471',
#        'type': 'a.k.a.',
#        'category': 'weak',
#        'lastName': 'RZHD'}]},
#     'addressList': {'address': {'uid': '52044',
#       'address1': 'Novaya Basmannaya Street, 2',
#       'city': 'Moscow',
#       'postalCode': '107174',
#       'country': 'Russia'}}},
#    {'uid': '46072',
#     'lastName': 'MYANMA OIL AND GAS ENTERPRISE',
#     'sdnType': 'Entity',
#     'programList': {'program': 'BURMA-EO14014'},
#     'idList': {'id': [{'uid': '166733',
#        'idType': 'Organization Established Date',
#        'idNumber': '1963'},
#       {'uid': '166734',
#        'idType': 'Organization Type:',
#        'idNumber': 'Extraction of crude petroleum'},
#       {'uid': '166737',
#        'idType': 'Target Type',
#        'idNumber': 'State-Owned Enterprise'},
#       {'uid': '166768',
#        'idType': 'Executive Order 14014 Directive Information:',
#        'idNumber': 'Subject to Directive 1 - As of the effective date, the provision, exportation, or reexportation, directly or indirectly, of financial services to or for the benefit of Myanma Oil and Gas Enterprise (MOGE) or its property or interests in property is prohibited.'},
#       {'uid': '166769',
#        'idType': 'Executive Order 14014 Directive Information:',
#        'idNumber': 'For more information on directives, please visit the following link: https://ofac.treasury.gov/sanctions-programs-and-country-information/burma#directives'},
#       {'uid': '166770',
#        'idType': 'Listing Date (EO 14014 Directive 1):',
#        'idNumber': '31 Oct 2023'},
#       {'uid': '166771',
#        'idType': 'Effective Date (EO 14014 Directive 1):',
#        'idNumber': '15 Dec 2023'}]},
#     'akaList': {'aka': [{'uid': '71179',
#        'type': 'a.k.a.',
#        'category': 'weak',
#        'lastName': 'MOGE'},
#       {'uid': '71180',
#        'type': 'a.k.a.',
#        'category': 'weak',
#        'lastName': 'M.O.G.E.'}]},
#     'addressList': {'address': [{'uid': '68654',
#        'address1': 'Complex No. 44',
#        'city': 'Nay Pyi Taw',
#        'stateOrProvince': 'Naypyidaw Union Territory',
#        'country': 'Burma'},
#       {'uid': '68655',
#        'address1': 'Building No. 6',
#        'city': 'Nay Pyi Taw',
#        'country': 'Burma'}]}}]}}

# %%
import json

json_content = json.dumps(xml_dict, indent=4)

with open('output.json', 'w') as json_file:
    json_file.write(json_content)
